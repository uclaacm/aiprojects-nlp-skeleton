# %% [markdown]
# # Embeddings Demo using PyTorch

# %% [markdown]
# ## Word2Vec

# %% [markdown]
# ### Import Necessary Libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from collections import Counter
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %% [markdown]
# ### Prepare Corpus and **Vocabulary**

# %%
# Step 1: Prepare a simple corpus
corpus = "He is the king . The king is royal. She is the royal queen . He is a prince, and she is a princess ."

# Step 2: Tokenize and build vocabulary
tokens = corpus.lower().split()  # Tokenize and lower-case words
vocab = set(tokens)  # Create a set of unique words
word2idx = {word: idx for idx, word in enumerate(vocab)}  # Create word to index mapping
idx2word = {idx: word for word, idx in word2idx.items()}  # Create index to word mapping
vocab_size = len(vocab)  # Calculate the size of vocabulary

# %%
print("Tokens: ", tokens)
print("Vocabulary: ", vocab)
print("Word to index mapping: ", word2idx)
print("Index to word mapping: ", idx2word)
print("Vocabulary size: ", vocab_size)
# Out:
# Tokens:  ['he', 'is', 'the', 'king', '.', 'the', 'king', 'is', 'royal.', 'she', 'is', 'the', 'royal', 'queen', '.', 'he', 'is', 'a', 'prince,', 'and', 'she', 'is', 'a', 'princess', '.']
# Vocabulary:  {'king', 'and', 'a', 'he', 'is', 'royal.', 'she', 'royal', '.', 'princess', 'queen', 'prince,', 'the'}
# Word to index mapping:  {'king': 0, 'and': 1, 'a': 2, 'he': 3, 'is': 4, 'royal.': 5, 'she': 6, 'royal': 7, '.': 8, 'princess': 9, 'queen': 10, 'prince,': 11, 'the': 12}
# Index to word mapping:  {0: 'king', 1: 'and', 2: 'a', 3: 'he', 4: 'is', 5: 'royal.', 6: 'she', 7: 'royal', 8: '.', 9: 'princess', 10: 'queen', 11: 'prince,', 12: 'the'}
# Vocabulary size:  13

# %% [markdown]
# ### Create Dataset

# %%
context_window = 2  # Define the size of context window
data = []  # Initialize empty list to hold data

# Loop through each token and extract its context and target word
for i in range(context_window, len(tokens) - context_window):
    context = [tokens[i - t] for t in range(context_window, 0, -1)] + [tokens[i + t] for t in range(1, context_window + 1)]
    target = tokens[i]
    data.append((context, target))  # Append the context and target word as a tuple to the data list

# %% [markdown]
# ### Define Skip-gram Model

# %%
# Step 4: Define the Skip-gram model architecture
class SkipGram(nn.Module):
    def __init__(self, vocab_size, embed_dim):
        super(SkipGram, self).__init__()
        self.in_embed = nn.Embedding(vocab_size, embed_dim)
        self.out_embed = nn.Embedding(vocab_size, embed_dim)
        
        
    def forward(self, target, context):
        in_embeds = self.in_embed(target)
        out_embeds = self.out_embed(context)
        scores = torch.matmul(out_embeds, in_embeds.t())
        return scores.squeeze()

# %% [markdown]
# ### Initialize Model and Train

# %%
# Step 5: Initialize the model, loss, and optimizer
embed_dim = 50
model = SkipGram(vocab_size, embed_dim)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %%
print(model)
# Out:
# SkipGram(
#   (in_embed): Embedding(13, 50)
#   (out_embed): Embedding(13, 50)
# )

# %%
# Step 6: Training loop
epochs = 10
for epoch in range(epochs):
    total_loss = 0
    for context, target in data:
        print(context, target)
        context_idx = torch.tensor([word2idx[w] for w in context], dtype=torch.long)
        target_idx = torch.tensor([word2idx[target]], dtype=torch.long)
        
        print("Max context_idx:", torch.max(context_idx).item())  # Debug line
        print("Min context_idx:", torch.min(context_idx).item())  # Debug line

        print("context_idx shape:", context_idx.shape)  # Debug line
        print(context_idx)  # Debug line
        optimizer.zero_grad()
        scores = model(target_idx, context_idx)
        # change scores to be a float tensor

        print("Scores", scores)
        print("Scores shape:", scores.shape)  # Debug line
        print("Score dtype: ", scores.dtype)  # Debug line

        print("context_idx dtype: ", context_idx.dtype)  # Debug line

        context_idx = context_idx.float()
        print("context_idx: ", context_idx)
        loss = criterion(scores, context_idx)
        print(loss)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1)
        optimizer.step()
        print("Loss: ", loss.item()) # Debug line
        
        total_loss += loss.item()

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{epochs}], Loss: {total_loss/len(data):.4f}')
# Out:
# ['he', 'is', 'king', '.'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([3, 4, 0, 8])
# Scores tensor([-10.7856,  -5.3515,   3.3014, -10.2490], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([3., 4., 0., 8.])
# tensor(185.2784, grad_fn=<DivBackward1>)
# Loss:  185.27841186523438
# ['is', 'the', '.', 'the'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12,  8, 12])
# Scores tensor([-5.3809, -8.7242,  8.7315, -8.7242], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12.,  8., 12.])
# tensor(475.3839, grad_fn=<DivBackward1>)
# Loss:  475.3839416503906
# ['the', 'king', 'the', 'king'] .
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0, 12,  0])
# Scores tensor([-5.7535,  1.1268, -5.7535,  1.1268], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0., 12.,  0.])
# tensor(181.7876, grad_fn=<DivBackward1>)
# Loss:  181.78762817382812
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([ 2.5982, -9.7033,  2.5982, -5.1088], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(137.5604, grad_fn=<DivBackward1>)
# Loss:  137.5604248046875
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([ 8.0148, -8.0835, -5.3168,  0.1599], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(285.7926, grad_fn=<DivBackward1>)
# Loss:  285.7925720214844
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([  8.7690,  -0.6172,   4.5042, -12.6514], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(150.1689, grad_fn=<DivBackward1>)
# Loss:  150.16885375976562
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([-3.8493, -8.0994, -5.1981, -8.0994], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(45.6372, grad_fn=<DivBackward1>)
# Loss:  45.63716125488281
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([-0.7386, -8.4459, -0.7386,  4.3990], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(105.6179, grad_fn=<DivBackward1>)
# Loss:  105.617919921875
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([  4.8410, -12.2314,   8.0323,  -1.7709], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(207.3711, grad_fn=<DivBackward1>)
# Loss:  207.37109375
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([ 1.3887, -4.8362,  5.2751, -2.0672], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(137.7522, grad_fn=<DivBackward1>)
# Loss:  137.75222778320312
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([ -2.8010, -13.0173,   3.4082, -10.7725], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(335.4574, grad_fn=<DivBackward1>)
# Loss:  335.4573974609375
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-4.5549, -1.0366,  7.6982, -0.7437], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(233.5189, grad_fn=<DivBackward1>)
# Loss:  233.51890563964844
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# Scores tensor([-3.8295, -1.7430, -5.2157, -0.2404], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 7., 10.,  3.,  4.])
# tensor(60.5671, grad_fn=<DivBackward1>)
# Loss:  60.567100524902344
# ['queen', '.', 'is', 'a'] he
# Max context_idx: 10
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([10,  8,  4,  2])
# Scores tensor([ 2.8930,  8.8392,  5.4161, -1.5385], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([10.,  8.,  4.,  2.])
# tensor(94.7413, grad_fn=<DivBackward1>)
# Loss:  94.74130249023438
# ['.', 'he', 'a', 'prince,'] is
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 8,  3,  2, 11])
# Scores tensor([ 17.8256,   6.8793,   7.3115, -12.9595], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8.,  3.,  2., 11.])
# tensor(392.5049, grad_fn=<DivBackward1>)
# Loss:  392.5049133300781
# ['he', 'is', 'prince,', 'and'] a
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([ 3,  4, 11,  1])
# Scores tensor([ -2.4698,  -1.7999,  10.2728, -14.5177], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 3.,  4., 11.,  1.])
# tensor(111.3091, grad_fn=<DivBackward1>)
# Loss:  111.30905151367188
# ['is', 'a', 'and', 'she'] prince,
# Max context_idx: 6
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([4, 2, 1, 6])
# Scores tensor([ 1.5058,  9.8136, 18.7292, -8.2349], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([4., 2., 1., 6.])
# tensor(248.5110, grad_fn=<DivBackward1>)
# Loss:  248.51100158691406
# ['a', 'prince,', 'she', 'is'] and
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 2, 11,  6,  4])
# Scores tensor([-13.3422,  11.3059,   3.2636,  -7.7742], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 2., 11.,  6.,  4.])
# tensor(173.8774, grad_fn=<DivBackward1>)
# Loss:  173.87744140625
# ['prince,', 'and', 'is', 'a'] she
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([11,  1,  4,  2])
# Scores tensor([ 0.9317, -0.4042, -0.3163,  2.7671], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([11.,  1.,  4.,  2.])
# tensor(39.6721, grad_fn=<DivBackward1>)
# Loss:  39.67213439941406
# ['and', 'she', 'a', 'princess'] is
# Max context_idx: 9
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([1, 6, 2, 9])
# Scores tensor([ -5.5254, -11.9833,   7.5176,  -8.4845], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([1., 6., 2., 9.])
# tensor(274.0678, grad_fn=<DivBackward1>)
# Loss:  274.06781005859375
# ['she', 'is', 'princess', '.'] a
# Max context_idx: 9
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([6, 4, 9, 8])
# Scores tensor([ -7.3559,  -1.3856, -10.0591,   5.1374], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([6., 4., 9., 8.])
# tensor(237.8598, grad_fn=<DivBackward1>)
# Loss:  237.85977172851562
# ['he', 'is', 'king', '.'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([3, 4, 0, 8])
# Scores tensor([-10.4177,  -4.5832,   1.9091,  -8.9304], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([3., 4., 0., 8.])
# tensor(149.6888, grad_fn=<DivBackward1>)
# Loss:  149.68882751464844
# ['is', 'the', '.', 'the'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12,  8, 12])
# Scores tensor([-5.3365, -7.5977,  7.2549, -7.5977], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12.,  8., 12.])
# tensor(406.8288, grad_fn=<DivBackward1>)
# Loss:  406.8288269042969
# ['the', 'king', 'the', 'king'] .
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0, 12,  0])
# Scores tensor([-4.8557,  0.5310, -4.8557,  0.5310], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0., 12.,  0.])
# tensor(146.0277, grad_fn=<DivBackward1>)
# Loss:  146.02774047851562
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([ 1.2070, -8.3911,  1.2070, -4.3465], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(107.3393, grad_fn=<DivBackward1>)
# Loss:  107.3393325805664
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([ 6.5457, -6.9631, -5.2713,  0.4222], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(240.0542, grad_fn=<DivBackward1>)
# Loss:  240.05419921875
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([  7.0849,  -0.3593,   5.0084, -11.6559], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(125.5555, grad_fn=<DivBackward1>)
# Loss:  125.55545043945312
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([-4.5465, -7.6160, -5.0019, -7.6160], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(34.9381, grad_fn=<DivBackward1>)
# Loss:  34.938140869140625
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([-0.3103, -8.3243, -0.3103,  3.3844], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(89.3138, grad_fn=<DivBackward1>)
# Loss:  89.31375885009766
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([  5.1996, -11.1314,   6.3739,  -1.0947], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(171.2754, grad_fn=<DivBackward1>)
# Loss:  171.275390625
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([ 1.2508, -4.0835,  4.2520, -1.6346], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(111.6032, grad_fn=<DivBackward1>)
# Loss:  111.60324096679688
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([ -2.7612, -12.3246,   2.6650, -10.3127], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(305.5512, grad_fn=<DivBackward1>)
# Loss:  305.55120849609375
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-4.4610, -0.7119,  6.6891, -0.6877], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(207.7757, grad_fn=<DivBackward1>)
# Loss:  207.7757110595703
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# Scores tensor([-3.5597, -1.5877, -5.1384, -0.9295], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 7., 10.,  3.,  4.])
# tensor(48.9713, grad_fn=<DivBackward1>)
# Loss:  48.97132873535156
# ['queen', '.', 'is', 'a'] he
# Max context_idx: 10
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([10,  8,  4,  2])
# Scores tensor([ 3.3331,  8.0279,  5.4664, -1.4835], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([10.,  8.,  4.,  2.])
# tensor(78.2060, grad_fn=<DivBackward1>)
# Loss:  78.2060317993164
# ['.', 'he', 'a', 'prince,'] is
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 8,  3,  2, 11])
# Scores tensor([ 16.4103,   6.6785,   6.2349, -12.4337], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8.,  3.,  2., 11.])
# tensor(366.8328, grad_fn=<DivBackward1>)
# Loss:  366.832763671875
# ['he', 'is', 'prince,', 'and'] a
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([ 3,  4, 11,  1])
# Scores tensor([ -2.1257,  -1.4263,   9.4488, -14.4666], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 3.,  4., 11.,  1.])
# tensor(102.1399, grad_fn=<DivBackward1>)
# Loss:  102.1398696899414
# ['is', 'a', 'and', 'she'] prince,
# Max context_idx: 6
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([4, 2, 1, 6])
# Scores tensor([ 1.6467, 10.0168, 17.7484, -7.7798], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([4., 2., 1., 6.])
# tensor(233.0450, grad_fn=<DivBackward1>)
# Loss:  233.0449676513672
# ['a', 'prince,', 'she', 'is'] and
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 2, 11,  6,  4])
# Scores tensor([-13.2347,  10.4412,   3.6243,  -7.2952], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 2., 11.,  6.,  4.])
# tensor(159.2245, grad_fn=<DivBackward1>)
# Loss:  159.22451782226562
# ['prince,', 'and', 'is', 'a'] she
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([11,  1,  4,  2])
# Scores tensor([ 1.3549, -0.2935,  0.0911,  1.8469], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([11.,  1.,  4.,  2.])
# tensor(26.1457, grad_fn=<DivBackward1>)
# Loss:  26.14570426940918
# ['and', 'she', 'a', 'princess'] is
# Max context_idx: 9
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([1, 6, 2, 9])
# Scores tensor([ -5.3840, -10.7882,   6.4440,  -8.0316], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([1., 6., 2., 9.])
# tensor(245.5016, grad_fn=<DivBackward1>)
# Loss:  245.50155639648438
# ['she', 'is', 'princess', '.'] a
# Max context_idx: 9
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([6, 4, 9, 8])
# Scores tensor([-7.0552, -1.0150, -9.7620,  4.1553], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([6., 4., 9., 8.])
# tensor(213.3524, grad_fn=<DivBackward1>)
# Loss:  213.3523712158203
# ['he', 'is', 'king', '.'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([3, 4, 0, 8])
# Scores tensor([-10.0527,  -3.8278,   0.5190,  -7.6302], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([3., 4., 0., 8.])
# tensor(114.4935, grad_fn=<DivBackward1>)
# Loss:  114.49345397949219
# ['is', 'the', '.', 'the'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12,  8, 12])
# Scores tensor([-5.2844, -6.4769,  5.8016, -6.4769], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12.,  8., 12.])
# tensor(339.0280, grad_fn=<DivBackward1>)
# Loss:  339.0279846191406
# ['the', 'king', 'the', 'king'] .
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0, 12,  0])
# Scores tensor([-3.9584, -0.0591, -3.9584, -0.0591], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0., 12.,  0.])
# tensor(110.7005, grad_fn=<DivBackward1>)
# Loss:  110.70053100585938
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([-0.1823, -7.0928, -0.1823, -3.6016], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(77.4800, grad_fn=<DivBackward1>)
# Loss:  77.48001098632812
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([ 5.0988, -5.8478, -5.2179,  0.6717], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(195.1069, grad_fn=<DivBackward1>)
# Loss:  195.10693359375
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([  5.5235,  -0.0653,   4.9942, -10.4642], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(109.2787, grad_fn=<DivBackward1>)
# Loss:  109.2786865234375
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([-5.1972, -7.0447, -4.9654, -7.0447], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(26.6367, grad_fn=<DivBackward1>)
# Loss:  26.636688232421875
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([ 0.1273, -8.0593,  0.1273,  2.3097], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(74.3893, grad_fn=<DivBackward1>)
# Loss:  74.38931274414062
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([ 4.3918, -9.6912,  5.2936, -0.3624], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(144.3030, grad_fn=<DivBackward1>)
# Loss:  144.30303955078125
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([ 1.0755, -3.3555,  3.2462, -1.1932], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(87.0586, grad_fn=<DivBackward1>)
# Loss:  87.05862426757812
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([ -2.7231, -11.6675,   1.9065,  -9.8571], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(275.8465, grad_fn=<DivBackward1>)
# Loss:  275.84649658203125
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-4.2760, -0.3832,  5.6935, -0.6316], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(181.2698, grad_fn=<DivBackward1>)
# Loss:  181.26983642578125
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# Scores tensor([-3.2231, -1.5702, -5.0440, -1.6135], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 7., 10.,  3.,  4.])
# tensor(40.8698, grad_fn=<DivBackward1>)
# Loss:  40.86981201171875
# ['queen', '.', 'is', 'a'] he
# Max context_idx: 10
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([10,  8,  4,  2])
# Scores tensor([ 3.7993,  7.2393,  5.4988, -1.4199], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([10.,  8.,  4.,  2.])
# tensor(63.2098, grad_fn=<DivBackward1>)
# Loss:  63.20982360839844
# ['.', 'he', 'a', 'prince,'] is
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 8,  3,  2, 11])
# Scores tensor([ 15.0267,   6.5191,   5.2141, -11.9607], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8.,  3.,  2., 11.])
# tensor(342.0160, grad_fn=<DivBackward1>)
# Loss:  342.0160217285156
# ['he', 'is', 'prince,', 'and'] a
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([ 3,  4, 11,  1])
# Scores tensor([ -1.7739,  -1.0441,   8.6317, -14.4213], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 3.,  4., 11.,  1.])
# tensor(92.9744, grad_fn=<DivBackward1>)
# Loss:  92.9743881225586
# ['is', 'a', 'and', 'she'] prince,
# Max context_idx: 6
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([4, 2, 1, 6])
# Scores tensor([ 1.7968, 10.2215, 16.7743, -7.2925], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([4., 2., 1., 6.])
# tensor(217.4344, grad_fn=<DivBackward1>)
# Loss:  217.4344482421875
# ['a', 'prince,', 'she', 'is'] and
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 2, 11,  6,  4])
# Scores tensor([-13.1357,   9.5852,   3.9672,  -6.8144], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 2., 11.,  6.,  4.])
# tensor(144.8311, grad_fn=<DivBackward1>)
# Loss:  144.8311004638672
# ['prince,', 'and', 'is', 'a'] she
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([11,  1,  4,  2])
# Scores tensor([ 1.7852, -0.1812,  0.3778,  0.9381], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([11.,  1.,  4.,  2.])
# tensor(20.0038, grad_fn=<DivBackward1>)
# Loss:  20.0037899017334
# ['and', 'she', 'a', 'princess'] is
# Max context_idx: 9
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([1, 6, 2, 9])
# Scores tensor([-5.3169, -9.3233,  5.4234, -7.5695], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([1., 6., 2., 9.])
# tensor(216.1581, grad_fn=<DivBackward1>)
# Loss:  216.15805053710938
# ['she', 'is', 'princess', '.'] a
# Max context_idx: 9
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([6, 4, 9, 8])
# Scores tensor([-6.7325, -0.6376, -9.4665,  3.1795], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([6., 4., 9., 8.])
# tensor(189.1433, grad_fn=<DivBackward1>)
# Loss:  189.1432647705078
# ['he', 'is', 'king', '.'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([3, 4, 0, 8])
# Scores tensor([-9.6870, -3.0810, -0.8705, -6.3365], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([3., 4., 0., 8.])
# tensor(80.6386, grad_fn=<DivBackward1>)
# Loss:  80.63862609863281
# ['is', 'the', '.', 'the'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12,  8, 12])
# Scores tensor([-5.2282, -5.3522,  4.3693, -5.3522], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12.,  8., 12.])
# tensor(271.7112, grad_fn=<DivBackward1>)
# Loss:  271.711181640625
# ['the', 'king', 'the', 'king'] .
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0, 12,  0])
# Scores tensor([-3.0666, -0.6349, -3.0666, -0.6349], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0., 12.,  0.])
# tensor(77.0170, grad_fn=<DivBackward1>)
# Loss:  77.01697540283203
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([-1.5630, -5.7736, -1.5630, -2.9052], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(48.9236, grad_fn=<DivBackward1>)
# Loss:  48.923561096191406
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([ 3.6727, -4.7280, -5.1604,  0.8880], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(151.8121, grad_fn=<DivBackward1>)
# Loss:  151.8120574951172
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([ 4.5113,  0.2761,  4.0561, -9.0028], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(94.8619, grad_fn=<DivBackward1>)
# Loss:  94.86193084716797
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([-5.7636, -6.4164, -5.1069, -6.4164], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(20.5835, grad_fn=<DivBackward1>)
# Loss:  20.583541870117188
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([ 0.7011, -7.6511,  0.7011,  1.2497], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(68.0949, grad_fn=<DivBackward1>)
# Loss:  68.09490966796875
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([ 3.3982, -8.2376,  4.2474,  0.3640], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(117.4525, grad_fn=<DivBackward1>)
# Loss:  117.45250701904297
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([ 0.8666, -2.7298,  2.2788, -0.7369], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(65.7330, grad_fn=<DivBackward1>)
# Loss:  65.73297119140625
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([ -2.6485, -11.0726,   1.1187,  -9.3964], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(246.2648, grad_fn=<DivBackward1>)
# Loss:  246.26475524902344
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-4.1032, -0.0577,  4.7072, -0.5755], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(155.3375, grad_fn=<DivBackward1>)
# Loss:  155.33753967285156
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# Scores tensor([-2.8149, -1.8018, -4.8993, -2.1859], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 7., 10.,  3.,  4.])
# tensor(35.6051, grad_fn=<DivBackward1>)
# Loss:  35.605064392089844
# ['queen', '.', 'is', 'a'] he
# Max context_idx: 10
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([10,  8,  4,  2])
# Scores tensor([ 4.3129,  6.4870,  5.4878, -1.3388], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([10.,  8.,  4.,  2.])
# tensor(50.8351, grad_fn=<DivBackward1>)
# Loss:  50.835060119628906
# ['.', 'he', 'a', 'prince,'] is
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 8,  3,  2, 11])
# Scores tensor([ 13.6783,   6.3581,   4.2139, -11.4844], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8.,  3.,  2., 11.])
# tensor(317.6979, grad_fn=<DivBackward1>)
# Loss:  317.6978759765625
# ['he', 'is', 'prince,', 'and'] a
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([ 3,  4, 11,  1])
# Scores tensor([ -1.4094,  -0.6570,   7.8240, -14.3801], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 3.,  4., 11.,  1.])
# tensor(83.8343, grad_fn=<DivBackward1>)
# Loss:  83.8343276977539
# ['is', 'a', 'and', 'she'] prince,
# Max context_idx: 6
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([4, 2, 1, 6])
# Scores tensor([ 2.0454, 10.4251, 15.8165, -6.8011], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([4., 2., 1., 6.])
# tensor(201.6324, grad_fn=<DivBackward1>)
# Loss:  201.6324462890625
# ['a', 'prince,', 'she', 'is'] and
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 2, 11,  6,  4])
# Scores tensor([-13.0453,   8.7321,   4.3107,  -6.3489], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 2., 11.,  6.,  4.])
# tensor(130.6815, grad_fn=<DivBackward1>)
# Loss:  130.6814727783203
# ['prince,', 'and', 'is', 'a'] she
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([11,  1,  4,  2])
# Scores tensor([ 2.1047, -0.0648,  0.0687,  0.2126], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([11.,  1.,  4.,  2.])
# tensor(20.0966, grad_fn=<DivBackward1>)
# Loss:  20.096649169921875
# ['and', 'she', 'a', 'princess'] is
# Max context_idx: 9
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([1, 6, 2, 9])
# Scores tensor([-5.2547, -7.8489,  4.3345, -7.1113], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([1., 6., 2., 9.])
# tensor(185.7031, grad_fn=<DivBackward1>)
# Loss:  185.70309448242188
# ['she', 'is', 'princess', '.'] a
# Max context_idx: 9
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([6, 4, 9, 8])
# Scores tensor([-6.4100, -0.2536, -9.1668,  2.2105], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([6., 4., 9., 8.])
# tensor(166.1853, grad_fn=<DivBackward1>)
# Loss:  166.18533325195312
# ['he', 'is', 'king', '.'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([3, 4, 0, 8])
# Scores tensor([-9.3063, -2.4314, -2.2413, -4.9870], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([3., 4., 0., 8.])
# tensor(53.4852, grad_fn=<DivBackward1>)
# Loss:  53.48524856567383
# ['is', 'the', '.', 'the'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12,  8, 12])
# Scores tensor([-5.0568, -4.3028,  2.9603, -4.3028], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12.,  8., 12.])
# tensor(206.4452, grad_fn=<DivBackward1>)
# Loss:  206.4451904296875
# ['the', 'king', 'the', 'king'] .
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0, 12,  0])
# Scores tensor([-2.2283, -1.1881, -2.2283, -1.1881], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0., 12.,  0.])
# tensor(48.8635, grad_fn=<DivBackward1>)
# Loss:  48.86351013183594
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([-2.8153, -4.3108, -2.8153, -2.5392], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(26.0363, grad_fn=<DivBackward1>)
# Loss:  26.036346435546875
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([ 2.2699, -3.6826, -4.9901,  1.0499], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(114.1464, grad_fn=<DivBackward1>)
# Loss:  114.14637756347656
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([ 3.4839,  0.5715,  3.0365, -7.5308], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(80.4440, grad_fn=<DivBackward1>)
# Loss:  80.44395446777344
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([-6.3120, -5.7036, -5.2843, -5.7036], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(17.1184, grad_fn=<DivBackward1>)
# Loss:  17.118371963500977
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([ 0.7014, -6.8806,  0.7014,  1.2233], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(64.2590, grad_fn=<DivBackward1>)
# Loss:  64.2590103149414
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([ 2.4067, -6.7447,  3.2710,  1.0628], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(92.6562, grad_fn=<DivBackward1>)
# Loss:  92.65617370605469
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([ 0.5974, -2.5382,  1.4211, -0.2613], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(51.0225, grad_fn=<DivBackward1>)
# Loss:  51.02250671386719
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([ -2.6298, -10.4809,   0.3147,  -8.9084], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(216.8578, grad_fn=<DivBackward1>)
# Loss:  216.8577880859375
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-3.9356,  0.2458,  3.7186, -0.5216], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(130.2280, grad_fn=<DivBackward1>)
# Loss:  130.22804260253906
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# Scores tensor([-2.4846, -2.1556, -4.6019, -2.7483], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 7., 10.,  3.,  4.])
# tensor(32.6114, grad_fn=<DivBackward1>)
# Loss:  32.61137390136719
# ['queen', '.', 'is', 'a'] he
# Max context_idx: 10
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([10,  8,  4,  2])
# Scores tensor([ 4.8904,  5.8130,  5.3144, -1.2412], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([10.,  8.,  4.,  2.])
# tensor(42.0327, grad_fn=<DivBackward1>)
# Loss:  42.032657623291016
# ['.', 'he', 'a', 'prince,'] is
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 8,  3,  2, 11])
# Scores tensor([ 12.3579,   6.1800,   3.1524, -10.9205], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8.,  3.,  2., 11.])
# tensor(293.0602, grad_fn=<DivBackward1>)
# Loss:  293.0602111816406
# ['he', 'is', 'prince,', 'and'] a
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([ 3,  4, 11,  1])
# Scores tensor([ -1.0158,  -0.3048,   7.0361, -14.3390], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 3.,  4., 11.,  1.])
# tensor(74.9126, grad_fn=<DivBackward1>)
# Loss:  74.91264343261719
# ['is', 'a', 'and', 'she'] prince,
# Max context_idx: 6
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([4, 2, 1, 6])
# Scores tensor([ 2.3301, 10.5342, 14.8630, -6.3261], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([4., 2., 1., 6.])
# tensor(186.0941, grad_fn=<DivBackward1>)
# Loss:  186.09408569335938
# ['a', 'prince,', 'she', 'is'] and
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 2, 11,  6,  4])
# Scores tensor([-12.9427,   7.8573,   4.7192,  -5.9036], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 2., 11.,  6.,  4.])
# tensor(116.4489, grad_fn=<DivBackward1>)
# Loss:  116.4488754272461
# ['prince,', 'and', 'is', 'a'] she
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([11,  1,  4,  2])
# Scores tensor([ 1.4295, -0.1277,  0.0651,  0.3449], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([11.,  1.,  4.,  2.])
# tensor(19.8070, grad_fn=<DivBackward1>)
# Loss:  19.80695343017578
# ['and', 'she', 'a', 'princess'] is
# Max context_idx: 9
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([1, 6, 2, 9])
# Scores tensor([-5.1612, -6.2764,  3.3417, -6.6510], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([1., 6., 2., 9.])
# tensor(156.1509, grad_fn=<DivBackward1>)
# Loss:  156.15087890625
# ['she', 'is', 'princess', '.'] a
# Max context_idx: 9
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([6, 4, 9, 8])
# Scores tensor([-6.0951,  0.0975, -8.8413,  1.2646], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([6., 4., 9., 8.])
# tensor(147.1107, grad_fn=<DivBackward1>)
# Loss:  147.11074829101562
# ['he', 'is', 'king', '.'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([3, 4, 0, 8])
# Scores tensor([-8.8411, -2.2025, -3.4167, -3.4237], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([3., 4., 0., 8.])
# tensor(36.6708, grad_fn=<DivBackward1>)
# Loss:  36.6707878112793
# ['is', 'the', '.', 'the'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12,  8, 12])
# Scores
# tensor([-4.8035, -3.1767,  1.6315, -3.1767], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12.,  8., 12.])
# tensor(141.7785, grad_fn=<DivBackward1>)
# Loss:  141.77850341796875
# ['the', 'king', 'the', 'king'] .
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0, 12,  0])
# Scores tensor([-1.3274, -1.7162, -1.3274, -1.7162], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0., 12.,  0.])
# tensor(29.0564, grad_fn=<DivBackward1>)
# Loss:  29.056377410888672
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([-3.7142, -2.8052, -3.7142, -2.6439], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(12.4616, grad_fn=<DivBackward1>)
# Loss:  12.461618423461914
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([ 0.9451, -2.5608, -4.7358,  1.0018], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(85.9125, grad_fn=<DivBackward1>)
# Loss:  85.91248321533203
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([ 2.5115,  0.7543,  2.0563, -5.9580], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(66.7019, grad_fn=<DivBackward1>)
# Loss:  66.70191955566406
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([-7.0397, -5.2510, -4.9862, -5.2510], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(15.8307, grad_fn=<DivBackward1>)
# Loss:  15.830745697021484
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([ 0.5466, -6.0980,  0.5466,  1.0724], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(59.5752, grad_fn=<DivBackward1>)
# Loss:  59.575233459472656
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([ 1.5367, -5.1379,  2.4342,  1.6955], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(74.1220, grad_fn=<DivBackward1>)
# Loss:  74.12203216552734
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([ 0.2204, -2.7074,  0.6847,  0.2325], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(43.3466, grad_fn=<DivBackward1>)
# Loss:  43.346649169921875
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([-2.6127, -9.8921, -0.4801, -8.4197], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(188.8129, grad_fn=<DivBackward1>)
# Loss:  188.81292724609375
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-3.7227,  0.4291,  2.7191, -0.4693], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(106.9353, grad_fn=<DivBackward1>)
# Loss:  106.93529510498047
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# ...
# Loss:  16.889116287231445
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([-5.1801, -1.3248, -5.1801, -1.6854], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(8.0862, grad_fn=<DivBackward1>)
# Loss:  8.086244583129883
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([-1.0417, -0.6465, -2.8452, -1.2873], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(39.4578, grad_fn=<DivBackward1>)
# Loss:  39.45777893066406
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([ 1.4044,  0.0823,  0.6381, -0.3103], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(29.0189, grad_fn=<DivBackward1>)
# Loss:  29.018939971923828
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([-7.7150, -5.0766, -4.3703, -5.0766], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(15.5091, grad_fn=<DivBackward1>)
# Loss:  15.509087562561035
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([ 0.0802, -3.7819,  0.0802,  0.9533], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(45.9604, grad_fn=<DivBackward1>)
# Loss:  45.96040344238281
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([0.5104, 0.4309, 1.4921, 0.8349], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(40.0573, grad_fn=<DivBackward1>)
# Loss:  40.05726623535156
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([-0.8185, -2.0944, -0.6222,  0.0841], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(37.9527, grad_fn=<DivBackward1>)
# Loss:  37.95269012451172
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([-3.0574, -7.9123, -2.7655, -7.1517], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(117.3393, grad_fn=<DivBackward1>)
# Loss:  117.33927154541016
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-2.2661,  0.2345,  0.2751, -0.4822], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(60.6340, grad_fn=<DivBackward1>)
# Loss:  60.633995056152344
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# Scores tensor([-2.4316, -2.7991, -3.9047, -3.5374], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 7., 10.,  3.,  4.])
# tensor(32.0077, grad_fn=<DivBackward1>)
# Loss:  32.00767517089844
# ['queen', '.', 'is', 'a'] he
# Max context_idx: 10
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([10,  8,  4,  2])
# Scores tensor([4.8656, 4.4713, 3.8294, 1.1882], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([10.,  8.,  4.,  2.])
# tensor(31.9319, grad_fn=<DivBackward1>)
# Loss:  31.931852340698242
# ['.', 'he', 'a', 'prince,'] is
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 8,  3,  2, 11])
# Scores tensor([ 8.1888,  5.8165, -0.0585, -9.1105], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8.,  3.,  2., 11.])
# tensor(216.0497, grad_fn=<DivBackward1>)
# Loss:  216.04966735839844
# ['he', 'is', 'prince,', 'and'] a
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([ 3,  4, 11,  1])
# Scores tensor([  0.2367,  -0.6220,   4.1821, -14.0103], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 3.,  4., 11.,  1.])
# tensor(49.7612, grad_fn=<DivBackward1>)
# Loss:  49.76123809814453
# ['is', 'a', 'and', 'she'] prince,
# Max context_idx: 6
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([4, 2, 1, 6])
# Scores tensor([ 3.7595, 10.6527, 11.2194, -4.0034], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([4., 2., 1., 6.])
# tensor(128.1567, grad_fn=<DivBackward1>)
# Loss:  128.1566925048828
# ['a', 'prince,', 'she', 'is'] and
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 2, 11,  6,  4])
# Scores tensor([-12.2367,   5.2282,   4.5488,  -4.0142], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 2., 11.,  6.,  4.])
# tensor(85.4090, grad_fn=<DivBackward1>)
# Loss:  85.40896606445312
# ['prince,', 'and', 'is', 'a'] she
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([11,  1,  4,  2])
# Scores tensor([ 0.7916, -0.7836, -0.4558, -0.3125], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([11.,  1.,  4.,  2.])
# tensor(19.6087, grad_fn=<DivBackward1>)
# Loss:  19.608675003051758
# ['and', 'she', 'a', 'princess'] is
# Max context_idx: 9
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([1, 6, 2, 9])
# Scores tensor([-4.8036,  1.0431,  0.1243, -4.4893], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([1., 6., 2., 9.])
# tensor(63.6079, grad_fn=<DivBackward1>)
# Loss:  63.607948303222656
# ['she', 'is', 'princess', '.'] a
# Max context_idx: 9
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([6, 4, 9, 8])
# Scores tensor([-4.4326, -0.2258, -7.0273, -0.7345], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([6., 4., 9., 8.])
# tensor(103.5033, grad_fn=<DivBackward1>)
# Loss:  103.50331115722656
# ['he', 'is', 'king', '.'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([3, 4, 0, 8])
# Scores tensor([-6.1946, -1.7614, -5.3199, -0.4899], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([3., 4., 0., 8.])
# tensor(26.0395, grad_fn=<DivBackward1>)
# Loss:  26.03951644897461
# ['is', 'the', '.', 'the'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12,  8, 12])
# Scores tensor([-2.1785, -0.8719, -1.1295, -0.8719], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12.,  8., 12.])
# tensor(47.3572, grad_fn=<DivBackward1>)
# Loss:  47.35716247558594
# ['the', 'king', 'the', 'king'] .
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0, 12,  0])
# Scores tensor([ 1.9340, -4.0790,  1.9340, -4.0790], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0., 12.,  0.])
# tensor(16.6942, grad_fn=<DivBackward1>)
# Loss:  16.69417953491211
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([-5.2277, -1.1695, -5.2277, -1.6251], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(7.9664, grad_fn=<DivBackward1>)
# Loss:  7.966408729553223
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([-1.8564, -0.6057, -1.7831, -2.0139], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(39.4233, grad_fn=<DivBackward1>)
# Loss:  39.42325973510742
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([ 0.8163, -0.4379,  0.4646,  0.4758], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(26.6479, grad_fn=<DivBackward1>)
# Loss:  26.647899627685547
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([-7.8836, -4.2530, -5.0664, -4.2530], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(17.5386, grad_fn=<DivBackward1>)
# Loss:  17.538618087768555
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([ 0.0195, -3.0437,  0.0195,  0.6146], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(41.9412, grad_fn=<DivBackward1>)
# Loss:  41.94117736816406
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([0.2342, 0.5095, 1.6402, 0.8314], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(40.4693, grad_fn=<DivBackward1>)
# Loss:  40.469303131103516
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([-0.5583, -2.0125, -0.7315, -0.5749], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(37.3754, grad_fn=<DivBackward1>)
# Loss:  37.375389099121094
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([-3.4043, -7.2424, -3.1429, -6.7451], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(99.3021, grad_fn=<DivBackward1>)
# Loss:  99.30210876464844
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-1.4234, -0.0688, -0.1733, -0.5787], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(49.0712, grad_fn=<DivBackward1>)
# Loss:  49.071189880371094
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# Scores tensor([-3.2603, -2.3059, -3.5340, -3.3736], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 7., 10.,  3.,  4.])
# tensor(31.5303, grad_fn=<DivBackward1>)
# Loss:  31.530349731445312
# ['queen', '.', 'is', 'a'] he
# Max context_idx: 10
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([10,  8,  4,  2])
# Scores tensor([4.2944, 4.4283, 3.6708, 1.9062], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([10.,  8.,  4.,  2.])
# tensor(30.6614, grad_fn=<DivBackward1>)
# Loss:  30.66143226623535
# ['.', 'he', 'a', 'prince,'] is
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 8,  3,  2, 11])
# Scores tensor([ 7.2677,  5.5709, -0.1427, -8.5107], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8.,  3.,  2., 11.])
# tensor(197.5238, grad_fn=<DivBackward1>)
# Loss:  197.52378845214844
# ['he', 'is', 'prince,', 'and'] a
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([ 3,  4, 11,  1])
# Scores tensor([  0.4997,  -0.8622,   3.4997, -13.9250], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 3.,  4., 11.,  1.])
# tensor(45.0250, grad_fn=<DivBackward1>)
# Loss:  45.024986267089844
# ['is', 'a', 'and', 'she'] prince,
# Max context_idx: 6
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([4, 2, 1, 6])
# Scores tensor([ 4.2370, 10.4014, 10.4678, -3.4582], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([4., 2., 1., 6.])
# tensor(117.2121, grad_fn=<DivBackward1>)
# Loss:  117.21209716796875
# ['a', 'prince,', 'she', 'is'] and
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 2, 11,  6,  4])
# Scores tensor([-11.9217,   4.5899,   4.3396,  -3.5684], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 2., 11.,  6.,  4.])
# tensor(80.4053, grad_fn=<DivBackward1>)
# Loss:  80.40531158447266
# ['prince,', 'and', 'is', 'a'] she
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([11,  1,  4,  2])
# Scores tensor([ 1.2090, -1.0277, -0.6276, -0.8038], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([11.,  1.,  4.,  2.])
# tensor(19.6625, grad_fn=<DivBackward1>)
# Loss:  19.66246795654297
# ['and', 'she', 'a', 'princess'] is
# Max context_idx: 9
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([1, 6, 2, 9])
# Scores tensor([-4.5700,  0.8364, -0.0355, -3.6434], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([1., 6., 2., 9.])
# tensor(53.9563, grad_fn=<DivBackward1>)
# Loss:  53.956329345703125
# ['she', 'is', 'princess', '.'] a
# Max context_idx: 9
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([6, 4, 9, 8])
# Scores tensor([-4.1915, -0.4479, -6.5704, -0.8924], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([6., 4., 9., 8.])
# tensor(94.9171, grad_fn=<DivBackward1>)
# Loss:  94.91709899902344
# Epoch [10/10], Loss: 53.3676

# %% [markdown]
# ### Evaluate Model

# %%
# Step 7: Evaluation
def most_similar(word, word2idx, idx2word, embedding_matrix, topk=5):
    word_embedding = embedding_matrix[word2idx[word]]
    similarities = cosine_similarity([word_embedding], embedding_matrix)[0]
    print([tup for tup in zip(idx2word.values(), similarities)])
    similar_words = [(idx2word[idx], similarities[idx]) for idx in np.argsort(similarities, axis=-1)[-topk-1:-1][::-1]]
    return similar_words

# %%
embedding_matrix = model.in_embed.weight.data.numpy()
# print(embedding_matrix) # Debug line
most_similar_words = most_similar('king', word2idx, idx2word, embedding_matrix, topk=5)
print(most_similar_words)
# Out:
# [('king', 0.99999994), ('and', 0.011666652), ('a', 0.17769969), ('he', -0.1712333), ('is', -0.0024271682), ('royal.', 0.015272625), ('she', -0.22830305), ('royal', -0.032777235), ('.', 0.09018909), ('princess', -0.1588235), ('queen', -0.20705464), ('prince,', 0.0042718425), ('the', 0.031071626)]
# [('a', 0.17769969), ('.', 0.09018909), ('the', 0.031071626), ('royal.', 0.015272625), ('and', 0.011666652)]

# %% [markdown]
# ## Using word2vec for Text Classification

# %% [markdown]
# ### Installing Required Libraries

# %%
# !pip install gensim torch

# %% [markdown]
# ### Loading Pre-trained Word2Vec Embeddings
#
# TODO: make sure to download the embeddings file from [kaggle](https://www.kaggle.com/datasets/leadbest/googlenewsvectorsnegative300) and place it in the same directory as this notebook

# %%
from gensim.models import KeyedVectors

# Load vectors directly from the file
model = KeyedVectors.load_word2vec_format('path/to/GoogleNews-vectors-negative300.bin', binary=True)

# %% [markdown]
# ### Converting Embeddings to PyTorch Tensors

# %%
vocab_size = len(model.index_to_key)
embedding_dim = model.vector_size

# Initialize a tensor to store the embeddings
embedding_matrix = torch.zeros((vocab_size, embedding_dim))

# Fill the tensor with the Word2Vec embeddings
for i, word in enumerate(model.index_to_key):
    embedding_matrix[i] = torch.tensor(model[word])

# Create an nn.Embedding layer and load the pre-trained embeddings
embedding_layer = torch.nn.Embedding.from_pretrained(embedding_matrix)

# %% [markdown]
# ### Building a Simple Text Classification Model

# %%
class TextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim, num_class):
        super().__init__()
        self.embedding = nn.Embedding.from_pretrained(embedding_matrix)
        self.fc1 = nn.Linear(embed_dim, 128)
        self.fc2 = nn.Linear(128, num_class)
        
    def forward(self, x):
        x = self.embedding(x)
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# ### Training the Model

# %%
# Training code here

# %% [markdown]
# ### Evaluating the Model

# %%
# Evaluation code here

# %% [markdown]
# ## GloVe

# %% [markdown]
# ### Loading Pre-trained GloVe Embeddings

# %%
from torchtext.vocab import GloVe
# Load GloVe vectors using torchtext
glove = GloVe(name='6B', dim=100)
# Out:
# .vector_cache\glove.6B.zip: 862MB [05:35, 2.57MB/s]
# 100%|█████████▉| 399999/400000 [01:26<00:00, 4607.26it/s]

# %% [markdown]
# ### Converting Embeddings to PyTorch Tensors

# %%
# Fetch the indices for the words in your vocabulary
word_indices = [glove.stoi[word] for word in ['hello', 'world']]

# Create a tensor with the GloVe embeddings
embedding_tensor = torch.stack([glove.vectors[i] for i in word_indices])

# %% [markdown]
# ### Building a Text Classification Model

# %%
import torch.nn as nn

class TextClassifier(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, num_class):
        super().__init__()
        self.embedding = nn.Embedding.from_pretrained(embedding_tensor)
        self.fc1 = nn.Linear(embedding_dim, 128)
        self.fc2 = nn.Linear(128, num_class)
        
    def forward(self, x):
        x = self.embedding(x)
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# ### Training the Model

# %%
# Training code here

# %% [markdown]
# ### Evaluating the Model

# %%
# Evaluation code here
