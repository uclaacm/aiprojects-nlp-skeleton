# %% [markdown]
# # Embeddings Demo using PyTorch

# %% [markdown]
# ## Word2Vec

# %% [markdown]
# ### Import Necessary Libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from collections import Counter
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %% [markdown]
# ### Prepare Corpus and **Vocabulary**

# %%
# Step 1: Prepare a simple corpus
corpus = "He is the king . The king is royal. She is the royal queen . He is a prince, and she is a princess ."

# Step 2: Tokenize and build vocabulary
tokens = corpus.lower().split()  # Tokenize and lower-case words
vocab = set(tokens)  # Create a set of unique words
word2idx = {word: idx for idx, word in enumerate(vocab)}  # Create word to index mapping
idx2word = {idx: word for word, idx in word2idx.items()}  # Create index to word mapping
vocab_size = len(vocab)  # Calculate the size of vocabulary

# %%
print("Tokens: ", tokens)
print("Vocabulary: ", vocab)
print("Word to index mapping: ", word2idx)
print("Index to word mapping: ", idx2word)
print("Vocabulary size: ", vocab_size)
# Out:
# Tokens:  ['he', 'is', 'the', 'king', '.', 'the', 'king', 'is', 'royal.', 'she', 'is', 'the', 'royal', 'queen', '.', 'he', 'is', 'a', 'prince,', 'and', 'she', 'is', 'a', 'princess', '.']
# Vocabulary:  {'she', 'is', 'he', 'royal', 'princess', 'royal.', 'king', 'and', 'a', 'prince,', 'queen', '.', 'the'}
# Word to index mapping:  {'she': 0, 'is': 1, 'he': 2, 'royal': 3, 'princess': 4, 'royal.': 5, 'king': 6, 'and': 7, 'a': 8, 'prince,': 9, 'queen': 10, '.': 11, 'the': 12}
# Index to word mapping:  {0: 'she', 1: 'is', 2: 'he', 3: 'royal', 4: 'princess', 5: 'royal.', 6: 'king', 7: 'and', 8: 'a', 9: 'prince,', 10: 'queen', 11: '.', 12: 'the'}
# Vocabulary size:  13

# %% [markdown]
# ### Create Dataset

# %%
context_window = 2  # Define the size of context window
data = []  # Initialize empty list to hold data

# Loop through each token and extract its context and target word
for i in range(context_window, len(tokens) - context_window):
    context = [tokens[i - t] for t in range(context_window, 0, -1)] + [tokens[i + t] for t in range(1, context_window + 1)]
    target = tokens[i]
    data.append((context, target))  # Append the context and target word as a tuple to the data list

# %% [markdown]
# ### Define Skip-gram Model

# %%
# Step 4: Define the Skip-gram model architecture
class SkipGram(nn.Module):
    def __init__(self, vocab_size, embed_dim):
        super(SkipGram, self).__init__()
        self.in_embed = nn.Embedding(vocab_size, embed_dim)
        self.out_embed = nn.Embedding(vocab_size, embed_dim)
        self.vocab_size = vocab_size
        
        
    def forward(self, target, context):
        in_embeds = self.in_embed(target)
        out_embeds = self.out_embed(context)
        scores = torch.matmul(out_embeds, in_embeds.t())
        return scores.squeeze()

# %% [markdown]
# ### Initialize Model and Train

# %%
# Step 5: Initialize the model, loss, and optimizer
embed_dim = 50
model = SkipGram(vocab_size, embed_dim)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %%
print(model)
# Out:
# SkipGram(
#   (in_embed): Embedding(13, 50)
#   (out_embed): Embedding(13, 50)
# )

# %%
# Step 6: Training loop
epochs = 10
for epoch in range(epochs):
    total_loss = 0
    for context, target in data:
        print(context, target)
        context_idx = torch.tensor([word2idx[w] for w in context], dtype=torch.long)
        target_idx = torch.tensor([word2idx[target]], dtype=torch.long)
        
        optimizer.zero_grad()
        scores = model(target_idx, context_idx)
        # change scores to be a float tensor

        context_idx = context_idx.float()
        loss = criterion(scores, context_idx)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1)
        optimizer.step()
        
        total_loss += loss.item()

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{epochs}], Loss: {total_loss/len(data):.4f}')
# Out:
# ['he', 'is', 'king', '.'] the
# ['is', 'the', '.', 'the'] king
# ['the', 'king', 'the', 'king'] .
# ['king', '.', 'king', 'is'] the
# ['.', 'the', 'is', 'royal.'] king
# ['the', 'king', 'royal.', 'she'] is
# ['king', 'is', 'she', 'is'] royal.
# ['is', 'royal.', 'is', 'the'] she
# ['royal.', 'she', 'the', 'royal'] is
# ['she', 'is', 'royal', 'queen'] the
# ['is', 'the', 'queen', '.'] royal
# ['the', 'royal', '.', 'he'] queen
# ['royal', 'queen', 'he', 'is'] .
# ['queen', '.', 'is', 'a'] he
# ['.', 'he', 'a', 'prince,'] is
# ['he', 'is', 'prince,', 'and'] a
# ['is', 'a', 'and', 'she'] prince,
# ['a', 'prince,', 'she', 'is'] and
# ['prince,', 'and', 'is', 'a'] she
# ['and', 'she', 'a', 'princess'] is
# ['she', 'is', 'princess', '.'] a
# ['he', 'is', 'king', '.'] the
# ['is', 'the', '.', 'the'] king
# ['the', 'king', 'the', 'king'] .
# ['king', '.', 'king', 'is'] the
# ['.', 'the', 'is', 'royal.'] king
# ['the', 'king', 'royal.', 'she'] is
# ['king', 'is', 'she', 'is'] royal.
# ['is', 'royal.', 'is', 'the'] she
# ['royal.', 'she', 'the', 'royal'] is
# ['she', 'is', 'royal', 'queen'] the
# ['is', 'the', 'queen', '.'] royal
# ['the', 'royal', '.', 'he'] queen
# ['royal', 'queen', 'he', 'is'] .
# ['queen', '.', 'is', 'a'] he
# ['.', 'he', 'a', 'prince,'] is
# ['he', 'is', 'prince,', 'and'] a
# ['is', 'a', 'and', 'she'] prince,
# ['a', 'prince,', 'she', 'is'] and
# ['prince,', 'and', 'is', 'a'] she
# ['and', 'she', 'a', 'princess'] is
# ['she', 'is', 'princess', '.'] a
# ['he', 'is', 'king', '.'] the
# ['is', 'the', '.', 'the'] king
# ['the', 'king', 'the', 'king'] .
# ['king', '.', 'king', 'is'] the
# ['.', 'the', 'is', 'royal.'] king
# ['the', 'king', 'royal.', 'she'] is
# ['king', 'is', 'she', 'is'] royal.
# ['is', 'royal.', 'is', 'the'] she
# ['royal.', 'she', 'the', 'royal'] is
# ['she', 'is', 'royal', 'queen'] the
# ['is', 'the', 'queen', '.'] royal
# ['the', 'royal', '.', 'he'] queen
# ['royal', 'queen', 'he', 'is'] .
# ['queen', '.', 'is', 'a'] he
# ['.', 'he', 'a', 'prince,'] is
# ['he', 'is', 'prince,', 'and'] a
# ['is', 'a', 'and', 'she'] prince,
# ['a', 'prince,', 'she', 'is'] and
# ['prince,', 'and', 'is', 'a'] she
# ['and', 'she', 'a', 'princess'] is
# ['she', 'is', 'princess', '.'] a
# ['he', 'is', 'king', '.'] the
# ['is', 'the', '.', 'the'] king
# ['the', 'king', 'the', 'king'] .
# ['king', '.', 'king', 'is'] the
# ['.', 'the', 'is', 'royal.'] king
# ['the', 'king', 'royal.', 'she'] is
# ['king', 'is', 'she', 'is'] royal.
# ['is', 'royal.', 'is', 'the'] she
# ['royal.', 'she', 'the', 'royal'] is
# ['she', 'is', 'royal', 'queen'] the
# ['is', 'the', 'queen', '.'] royal
# ['the', 'royal', '.', 'he'] queen
# ['royal', 'queen', 'he', 'is'] .
# ['queen', '.', 'is', 'a'] he
# ['.', 'he', 'a', 'prince,'] is
# ['he', 'is', 'prince,', 'and'] a
# ['is', 'a', 'and', 'she'] prince,
# ['a', 'prince,', 'she', 'is'] and
# ['prince,', 'and', 'is', 'a'] she
# ['and', 'she', 'a', 'princess'] is
# ['she', 'is', 'princess', '.'] a
# ['he', 'is', 'king', '.'] the
# ['is', 'the', '.', 'the'] king
# ['the', 'king', 'the', 'king'] .
# ['king', '.', 'king', 'is'] the
# ['.', 'the', 'is', 'royal.'] king
# ['the', 'king', 'royal.', 'she'] is
# ['king', 'is', 'she', 'is'] royal.
# ['is', 'royal.', 'is', 'the'] she
# ['royal.', 'she', 'the', 'royal'] is
# ['she', 'is', 'royal', 'queen'] the
# ['is', 'the', 'queen', '.'] royal
# ['the', 'royal', '.', 'he'] queen
# ['royal', 'queen', 'he', 'is'] .
# ['queen', '.', 'is', 'a'] he
# ['.', 'he', 'a', 'prince,'] is
# ['he', 'is', 'prince,', 'and'] a
# ['is', 'a', 'and', 'she'] prince,
# ['a', 'prince,', 'she', 'is'] and
# ['prince,', 'and', 'is', 'a'] she
# ['and', 'she', 'a', 'princess'] is
# ['she', 'is', 'princess', '.'] a
# ['he', 'is', 'king', '.'] the
# ['is', 'the', '.', 'the'] king
# ['the', 'king', 'the', 'king'] .
# ['king', '.', 'king', 'is'] the
# ['.', 'the', 'is', 'royal.'] king
# ['the', 'king', 'royal.', 'she'] is
# ['king', 'is', 'she', 'is'] royal.
# ['is', 'royal.', 'is', 'the'] she
# ['royal.', 'she', 'the', 'royal'] is
# ['she', 'is', 'royal', 'queen'] the
# ['is', 'the', 'queen', '.'] royal
# ['the', 'royal', '.', 'he'] queen
# ['royal', 'queen', 'he', 'is'] .
# ['queen', '.', 'is', 'a'] he
# ['.', 'he', 'a', 'prince,'] is
# ['he', 'is', 'prince,', 'and'] a
# ['is', 'a', 'and', 'she'] prince,
# ['a', 'prince,', 'she', 'is'] and
# ['prince,', 'and', 'is', 'a'] she
# ['and', 'she', 'a', 'princess'] is
# ['she', 'is', 'princess', '.'] a
# ['he', 'is', 'king', '.'] the
# ['is', 'the', '.', 'the'] king
# ['the', 'king', 'the', 'king'] .
# ['king', '.', 'king', 'is'] the
# ['.', 'the', 'is', 'royal.'] king
# ['the', 'king', 'royal.', 'she'] is
# ['king', 'is', 'she', 'is'] royal.
# ['is', 'royal.', 'is', 'the'] she
# ['royal.', 'she', 'the', 'royal'] is
# ['she', 'is', 'royal', 'queen'] the
# ['is', 'the', 'queen', '.'] royal
# ['the', 'royal', '.', 'he'] queen
# ['royal', 'queen', 'he', 'is'] .
# ['queen', '.', 'is', 'a'] he
# ['.', 'he', 'a', 'prince,'] is
# ['he', 'is', 'prince,', 'and'] a
# ['is', 'a', 'and', 'she'] prince,
# ['a', 'prince,', 'she', 'is'] and
# ['prince,', 'and', 'is', 'a'] she
# ['and', 'she', 'a', 'princess'] is
# ['she', 'is', 'princess', '.'] a
# ['he', 'is', 'king', '.'] the
# ['is', 'the', '.', 'the'] king
# ['the', 'king', 'the', 'king'] .
# ['king', '.', 'king', 'is'] the
# ['.', 'the', 'is', 'royal.'] king
# ['the', 'king', 'royal.', 'she'] is
# ['king', 'is', 'she', 'is'] royal.
# ['is', 'royal.', 'is', 'the'] she
# ['royal.', 'she', 'the', 'royal'] is
# ['she', 'is', 'royal', 'queen'] the
# ['is', 'the', 'queen', '.'] royal
# ['the', 'royal', '.', 'he'] queen
# ['royal', 'queen', 'he', 'is'] .
# ['queen', '.', 'is', 'a'] he
# ['.', 'he', 'a', 'prince,'] is
# ['he', 'is', 'prince,', 'and'] a
# ['is', 'a', 'and', 'she'] prince,
# ['a', 'prince,', 'she', 'is'] and
# ['prince,', 'and', 'is', 'a'] she
# ['and', 'she', 'a', 'princess'] is
# ['she', 'is', 'princess', '.'] a
# ['he', 'is', 'king', '.'] the
# ['is', 'the', '.', 'the'] king
# ['the', 'king', 'the', 'king'] .
# ['king', '.', 'king', 'is'] the
# ['.', 'the', 'is', 'royal.'] king
# ['the', 'king', 'royal.', 'she'] is
# ['king', 'is', 'she', 'is'] royal.
# ['is', 'royal.', 'is', 'the'] she
# ['royal.', 'she', 'the', 'royal'] is
# ['she', 'is', 'royal', 'queen'] the
# ['is', 'the', 'queen', '.'] royal
# ['the', 'royal', '.', 'he'] queen
# ['royal', 'queen', 'he', 'is'] .
# ['queen', '.', 'is', 'a'] he
# ['.', 'he', 'a', 'prince,'] is
# ['he', 'is', 'prince,', 'and'] a
# ['is', 'a', 'and', 'she'] prince,
# ['a', 'prince,', 'she', 'is'] and
# ['prince,', 'and', 'is', 'a'] she
# ['and', 'she', 'a', 'princess'] is
# ['she', 'is', 'princess', '.'] a
# ['he', 'is', 'king', '.'] the
# ['is', 'the', '.', 'the'] king
# ['the', 'king', 'the', 'king'] .
# ['king', '.', 'king', 'is'] the
# ['.', 'the', 'is', 'royal.'] king
# ['the', 'king', 'royal.', 'she'] is
# ['king', 'is', 'she', 'is'] royal.
# ['is', 'royal.', 'is', 'the'] she
# ['royal.', 'she', 'the', 'royal'] is
# ['she', 'is', 'royal', 'queen'] the
# ['is', 'the', 'queen', '.'] royal
# ['the', 'royal', '.', 'he'] queen
# ['royal', 'queen', 'he', 'is'] .
# ['queen', '.', 'is', 'a'] he
# ['.', 'he', 'a', 'prince,'] is
# ['he', 'is', 'prince,', 'and'] a
# ['is', 'a', 'and', 'she'] prince,
# ['a', 'prince,', 'she', 'is'] and
# ['prince,', 'and', 'is', 'a'] she
# ['and', 'she', 'a', 'princess'] is
# ['she', 'is', 'princess', '.'] a
# Epoch [10/10], Loss: 42.8685

# %% [markdown]
# ### Evaluate Model

# %%
# Step 7: Evaluation
def most_similar(word, word2idx, idx2word, embedding_matrix, topk=5):
    word_embedding = embedding_matrix[word2idx[word]]
    similarities = cosine_similarity([word_embedding], embedding_matrix)[0]
    print([tup for tup in zip(idx2word.values(), similarities)])
    similar_words = [(idx2word[idx], similarities[idx]) for idx in np.argsort(similarities, axis=-1)[-topk-1:-1][::-1]]
    return similar_words

# %%
embedding_matrix = model.in_embed.weight.data.numpy()
# print(embedding_matrix) # Debug line
most_similar_words = most_similar('king', word2idx, idx2word, embedding_matrix, topk=5)
print(most_similar_words)
# Out:
# [('she', -0.054763723), ('is', 0.21376781), ('he', -0.28846323), ('royal', 0.010742761), ('princess', -0.034592204), ('royal.', -0.13777846), ('king', 1.0), ('and', 0.2220083), ('a', 0.07711916), ('prince,', 0.041429013), ('queen', 0.07838805), ('.', 0.23037651), ('the', 0.14389211)]
# [('.', 0.23037651), ('and', 0.2220083), ('is', 0.21376781), ('the', 0.14389211), ('queen', 0.07838805)]

# %%
# Initialize a tensor to store the embeddings
embedding_matrix = torch.zeros((vocab_size, embed_dim))
# Fill the tensor with the Word2Vec embeddings
for i, word in enumerate(idx2word.values()):
    embedding_matrix[i] = torch.tensor(model[word])

# Create an nn.Embedding layer and load the pre-trained embeddings
embedding_layer = torch.nn.Embedding.from_pretrained(embedding_matrix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\ACM AI\aiprojects-nlp-skeleton\embeddingsDemo\embeddingsDemo.ipynb Cell 19 line 6
#       <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X64sZmlsZQ%3D%3D?line=3'>4</a> # Fill the tensor with the Word2Vec embeddings
#       <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X64sZmlsZQ%3D%3D?line=4'>5</a> for i, word in enumerate(idx2word.values()):
# ----> <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X64sZmlsZQ%3D%3D?line=5'>6</a>     embedding_matrix[i] = torch.tensor(model[word])
#       <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X64sZmlsZQ%3D%3D?line=7'>8</a> # Create an nn.Embedding layer and load the pre-trained embeddings
#       <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X64sZmlsZQ%3D%3D?line=8'>9</a> embedding_layer = torch.nn.Embedding.from_pretrained(embedding_matrix)
#
# TypeError: 'SkipGram' object is not subscriptable

# %%
class TextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim, num_class):
        super().__init__()
        self.embedding = nn.Embedding.from_pretrained(embedding_matrix)
        self.fc1 = nn.Linear(embed_dim, 128)
        self.fc2 = nn.Linear(128, num_class)
        
    def forward(self, x):
        x = self.embedding(x)
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# ## Using word2vec for Text Classification

# %% [markdown]
# ### Installing Required Libraries

# %%
# !pip install gensim torch

# %% [markdown]
# ### Loading Pre-trained Word2Vec Embeddings
#
# TODO: make sure to download the embeddings file from [kaggle](https://www.kaggle.com/datasets/leadbest/googlenewsvectorsnegative300) and place it in the same directory as this notebook

# %%
from gensim.models import KeyedVectors

# Load vectors directly from the file
model = KeyedVectors.load_word2vec_format('path/to/GoogleNews-vectors-negative300.bin', binary=True)

# %% [markdown]
# ### Converting Embeddings to PyTorch Tensors

# %%
vocab_size = len(model.index_to_key)
embedding_dim = model.vector_size

# Initialize a tensor to store the embeddings
embedding_matrix = torch.zeros((vocab_size, embedding_dim))

# Fill the tensor with the Word2Vec embeddings
for i, word in enumerate(model.index_to_key):
    embedding_matrix[i] = torch.tensor(model[word])

# Create an nn.Embedding layer and load the pre-trained embeddings
embedding_layer = torch.nn.Embedding.from_pretrained(embedding_matrix)

# %% [markdown]
# ### Building a Simple Text Classification Model

# %%
class TextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim, num_class):
        super().__init__()
        self.embedding = nn.Embedding.from_pretrained(embedding_matrix)
        self.fc1 = nn.Linear(embed_dim, 128)
        self.fc2 = nn.Linear(128, num_class)
        
    def forward(self, x):
        x = self.embedding(x)
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# ### Training the Model

# %%
# Training code here

# %% [markdown]
# ### Evaluating the Model

# %%
# Evaluation code here

# %% [markdown]
# ## GloVe

# %% [markdown]
# ### Loading Pre-trained GloVe Embeddings

# %%
from torchtext.vocab import GloVe
# Load GloVe vectors using torchtext
glove = GloVe(name='6B', dim=100)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# d:\ACM AI\aiprojects-nlp-skeleton\embeddingsDemo\embeddingsDemo.ipynb Cell 34 line 3
#       <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> from torchtext.vocab import GloVe
#       <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a> # Load GloVe vectors using torchtext
# ----> <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a> glove = GloVe(name='6B', dim=100)
#
# File d:\anaconda3\envs\pytorch\Lib\site-packages\torchtext\vocab\vectors.py:223, in GloVe.__init__(self, name, dim, **kwargs)
#     221 url = self.url[name]
#     222 name = "glove.{}.{}d.txt".format(name, str(dim))
# --> 223 super(GloVe, self).__init__(name, url=url, **kwargs)
#
# File d:\anaconda3\envs\pytorch\Lib\site-packages\torchtext\vocab\vectors.py:59, in Vectors.__init__(self, name, cache, url, unk_init, max_vectors)
#      57 self.dim = None
#      58 self.unk_init = torch.Tensor.zero_ if unk_init is None else unk_init
# ---> 59 self.cache(name, cache, url=url, max_vectors=max_vectors)
#
# File d:\anaconda3\envs\pytorch\Lib\site-packages\torchtext\vocab\vectors.py:173, in Vectors.cache(self, name, cache, url, max_vectors)
#     171 else:
#     172     logger.info("Loading vectors from {}".format(path_pt))
# --> 173     self.itos, self.stoi, self.vectors, self.dim = torch.load(path_pt)
#
# File d:\anaconda3\envs\pytorch\Lib\site-packages\torch\serialization.py:993, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     991 orig_position = opened_file.tell()
#     992 overall_storage = None
# --> 993 with _open_zipfile_reader(opened_file) as opened_zipfile:
#     994     if _is_torchscript_zip(opened_zipfile):
#     995         warnings.warn("'torch.load' received a zip file that looks like a TorchScript archive"
#     996                       " dispatching to 'torch.jit.load' (call 'torch.jit.load' directly to"
#     997                       " silence this warning)", UserWarning)
#
# File d:\anaconda3\envs\pytorch\Lib\site-packages\torch\serialization.py:447, in _open_zipfile_reader.__init__(self, name_or_buffer)
#     446 def __init__(self, name_or_buffer) -> None:
# --> 447     super().__init__(torch._C.PyTorchFileReader(name_or_buffer))
#
# RuntimeError: PytorchStreamReader failed reading zip archive: failed finding central directory

# %% [markdown]
# ### Converting Embeddings to PyTorch Tensors

# %%
# Fetch the indices for the words in your vocabulary
word_indices = [glove.stoi[word] for word in ['hello', 'world']]

# Create a tensor with the GloVe embeddings
embedding_tensor = torch.stack([glove.vectors[i] for i in word_indices])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\ACM AI\aiprojects-nlp-skeleton\embeddingsDemo\embeddingsDemo.ipynb Cell 36 line 2
#       <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X60sZmlsZQ%3D%3D?line=0'>1</a> # Fetch the indices for the words in your vocabulary
# ----> <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X60sZmlsZQ%3D%3D?line=1'>2</a> word_indices = [glove.stoi[word] for word in ['hello', 'world']]
#       <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X60sZmlsZQ%3D%3D?line=3'>4</a> # Create a tensor with the GloVe embeddings
#       <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X60sZmlsZQ%3D%3D?line=4'>5</a> embedding_tensor = torch.stack([glove.vectors[i] for i in word_indices])
#
# d:\ACM AI\aiprojects-nlp-skeleton\embeddingsDemo\embeddingsDemo.ipynb Cell 36 line 2
#       <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X60sZmlsZQ%3D%3D?line=0'>1</a> # Fetch the indices for the words in your vocabulary
# ----> <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X60sZmlsZQ%3D%3D?line=1'>2</a> word_indices = [glove.stoi[word] for word in ['hello', 'world']]
#       <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X60sZmlsZQ%3D%3D?line=3'>4</a> # Create a tensor with the GloVe embeddings
#       <a href='vscode-notebook-cell:/d%3A/ACM%20AI/aiprojects-nlp-skeleton/embeddingsDemo/embeddingsDemo.ipynb#X60sZmlsZQ%3D%3D?line=4'>5</a> embedding_tensor = torch.stack([glove.vectors[i] for i in word_indices])
#
# NameError: name 'glove' is not defined

# %% [markdown]
# ### Building a Text Classification Model

# %%
import torch.nn as nn

class TextClassifier(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, num_class):
        super().__init__()
        self.embedding = nn.Embedding.from_pretrained(embedding_tensor)
        self.fc1 = nn.Linear(embedding_dim, 128)
        self.fc2 = nn.Linear(128, num_class)
        
    def forward(self, x):
        x = self.embedding(x)
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# ### Training the Model

# %%
# Training code here

# %% [markdown]
# ### Evaluating the Model

# %%
# Evaluation code here
