# %% [markdown]
# # Embeddings Demo using PyTorch

# %% [markdown]
# ## Word2Vec

# %% [markdown]
# ### Import Necessary Libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from collections import Counter
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %% [markdown]
# ### Prepare Corpus and **Vocabulary**

# %%
# Step 1: Prepare a simple corpus
corpus = "He is the king . The king is royal. She is the royal queen . He is a prince, and she is a princess ."

# Step 2: Tokenize and build vocabulary
tokens = corpus.lower().split()  # Tokenize and lower-case words
vocab = set(tokens)  # Create a set of unique words
word2idx = {word: idx for idx, word in enumerate(vocab)}  # Create word to index mapping
idx2word = {idx: word for word, idx in word2idx.items()}  # Create index to word mapping
vocab_size = len(vocab)  # Calculate the size of vocabulary

# %%
print("Tokens: ", tokens)
print("Vocabulary: ", vocab)
print("Word to index mapping: ", word2idx)
print("Index to word mapping: ", idx2word)
print("Vocabulary size: ", vocab_size)
# Out:
# Tokens:  ['he', 'is', 'the', 'king', '.', 'the', 'king', 'is', 'royal.', 'she', 'is', 'the', 'royal', 'queen', '.', 'he', 'is', 'a', 'prince,', 'and', 'she', 'is', 'a', 'princess', '.']
# Vocabulary:  {'king', 'and', 'a', 'he', 'is', 'royal.', 'she', 'royal', '.', 'princess', 'queen', 'prince,', 'the'}
# Word to index mapping:  {'king': 0, 'and': 1, 'a': 2, 'he': 3, 'is': 4, 'royal.': 5, 'she': 6, 'royal': 7, '.': 8, 'princess': 9, 'queen': 10, 'prince,': 11, 'the': 12}
# Index to word mapping:  {0: 'king', 1: 'and', 2: 'a', 3: 'he', 4: 'is', 5: 'royal.', 6: 'she', 7: 'royal', 8: '.', 9: 'princess', 10: 'queen', 11: 'prince,', 12: 'the'}
# Vocabulary size:  13

# %% [markdown]
# ### Create Dataset

# %%
context_window = 2  # Define the size of context window
data = []  # Initialize empty list to hold data

# Loop through each token and extract its context and target word
for i in range(context_window, len(tokens) - context_window):
    context = [tokens[i - t] for t in range(context_window, 0, -1)] + [tokens[i + t] for t in range(1, context_window + 1)]
    target = tokens[i]
    data.append((context, target))  # Append the context and target word as a tuple to the data list

# %% [markdown]
# ### Define Skip-gram Model

# %%
# Step 4: Define the Skip-gram model architecture
class SkipGram(nn.Module):
    def __init__(self, vocab_size, embed_dim):
        super(SkipGram, self).__init__()
        self.in_embed = nn.Embedding(vocab_size, embed_dim)
        self.out_embed = nn.Embedding(vocab_size, embed_dim)
        
        
    def forward(self, target, context):
        in_embeds = self.in_embed(target)
        out_embeds = self.out_embed(context)
        scores = torch.matmul(out_embeds, in_embeds.t())
        return scores.squeeze()

# %% [markdown]
# ### Initialize Model and Train

# %%
# Step 5: Initialize the model, loss, and optimizer
embed_dim = 50
model = SkipGram(vocab_size, embed_dim)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %%
print(model)
# Out:
# SkipGram(
#   (in_embed): Embedding(13, 50)
#   (out_embed): Embedding(13, 50)
# )

# %%
# Step 6: Training loop
epochs = 10
for epoch in range(epochs):
    total_loss = 0
    for context, target in data:
        print(context, target)
        context_idx = torch.tensor([word2idx[w] for w in context], dtype=torch.long)
        target_idx = torch.tensor([word2idx[target]], dtype=torch.long)
        
        print("Max context_idx:", torch.max(context_idx).item())  # Debug line
        print("Min context_idx:", torch.min(context_idx).item())  # Debug line

        print("context_idx shape:", context_idx.shape)  # Debug line
        print(context_idx)  # Debug line
        optimizer.zero_grad()
        scores = model(target_idx, context_idx)
        # change scores to be a float tensor

        print("Scores", scores)
        print("Scores shape:", scores.shape)  # Debug line
        print("Score dtype: ", scores.dtype)  # Debug line

        print("context_idx dtype: ", context_idx.dtype)  # Debug line

        context_idx = context_idx.float()
        print("context_idx: ", context_idx)
        loss = criterion(scores, context_idx)
        print(loss)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1)
        optimizer.step()
        print("Loss: ", loss.item()) # Debug line
        
        total_loss += loss.item()

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{epochs}], Loss: {total_loss/len(data):.4f}')
# Out:
# ['he', 'is', 'king', '.'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([3, 4, 0, 8])
# Scores tensor([  6.0168,  -6.7091,   3.7314, -10.5706], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([3., 4., 0., 8.])
# tensor(185.0557, grad_fn=<DivBackward1>)
# Loss:  185.0556640625
# ['is', 'the', '.', 'the'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12,  8, 12])
# Scores tensor([-7.5164, -4.4246, 10.0371, -4.4246], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12.,  8., 12.])
# tensor(417.2960, grad_fn=<DivBackward1>)
# Loss:  417.29595947265625
# ['the', 'king', 'the', 'king'] .
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0, 12,  0])
# Scores tensor([12.4147, -1.2226, 12.4147, -1.2226], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0., 12.,  0.])
# tensor(16.6356, grad_fn=<DivBackward1>)
# Loss:  16.635560989379883
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([ 3.6568, -9.8290,  3.6568, -6.3948], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(156.4110, grad_fn=<DivBackward1>)
# Loss:  156.41104125976562
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([ 9.0481, -3.6713, -7.4569,  8.6070], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(235.2637, grad_fn=<DivBackward1>)
# Loss:  235.26370239257812
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([ 4.3660, -5.2648,  0.8486,  2.5092], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(32.6491, grad_fn=<DivBackward1>)
# Loss:  32.649131774902344
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([ 3.1309, -1.9398, -9.9668, -1.9398], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(119.3269, grad_fn=<DivBackward1>)
# Loss:  119.32685089111328
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([-10.9561,   4.5157, -10.9561,   3.9422], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(141.8311, grad_fn=<DivBackward1>)
# Loss:  141.83114624023438
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([ 1.2153,  2.7908,  3.4694, 22.3468], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(449.5221, grad_fn=<DivBackward1>)
# Loss:  449.5220642089844
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([-10.6236,  -5.9598,  -5.3825,  -7.5854], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(69.7474, grad_fn=<DivBackward1>)
# Loss:  69.74742126464844
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([-4.3202, 13.2085,  1.5863, 17.0756], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(287.5857, grad_fn=<DivBackward1>)
# Loss:  287.5856628417969
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-7.8368,  4.8854,  0.3582, 12.5303], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(395.3097, grad_fn=<DivBackward1>)
# Loss:  395.3096923828125
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# Scores tensor([ 9.4945, -3.9896,  1.0763, -2.6688], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 7., 10.,  3.,  4.])
# tensor(208.7540, grad_fn=<DivBackward1>)
# Loss:  208.7540283203125
# ['queen', '.', 'is', 'a'] he
# Max context_idx: 10
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([10,  8,  4,  2])
# Scores tensor([ 1.7304, -0.2448,  5.6896,  1.4815], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([10.,  8.,  4.,  2.])
# tensor(96.3448, grad_fn=<DivBackward1>)
# Loss:  96.34477233886719
# ['.', 'he', 'a', 'prince,'] is
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 8,  3,  2, 11])
# Scores tensor([ 7.4539, -1.3172, -8.4042,  0.1936], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8.,  3.,  2., 11.])
# tensor(137.9135, grad_fn=<DivBackward1>)
# Loss:  137.91351318359375
# ['he', 'is', 'prince,', 'and'] a
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([ 3,  4, 11,  1])
# Scores tensor([ 1.5747,  2.9708, -0.0917, -4.7321], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 3.,  4., 11.,  1.])
# tensor(50.4867, grad_fn=<DivBackward1>)
# Loss:  50.48672866821289
# ['is', 'a', 'and', 'she'] prince,
# Max context_idx: 6
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([4, 2, 1, 6])
# Scores tensor([ 7.2783,  2.4731,  4.2858, -2.9232], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([4., 2., 1., 6.])
# tensor(74.5492, grad_fn=<DivBackward1>)
# Loss:  74.54920196533203
# ['a', 'prince,', 'she', 'is'] and
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 2, 11,  6,  4])
# Scores tensor([  1.5053,  -8.6392,  13.7301, -15.0436], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 2., 11.,  6.,  4.])
# tensor(385.6071, grad_fn=<DivBackward1>)
# Loss:  385.6070861816406
# ['prince,', 'and', 'is', 'a'] she
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([11,  1,  4,  2])
# Scores tensor([ 14.3294, -16.3912, -10.3728,  -5.4570], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([11.,  1.,  4.,  2.])
# tensor(169.1020, grad_fn=<DivBackward1>)
# Loss:  169.10202026367188
# ['and', 'she', 'a', 'princess'] is
# Max context_idx: 9
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([1, 6, 2, 9])
# Scores tensor([ 1.5289,  2.9065, -8.3979,  1.3637], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([1., 6., 2., 9.])
# tensor(44.7576, grad_fn=<DivBackward1>)
# Loss:  44.75760269165039
# ['she', 'is', 'princess', '.'] a
# Max context_idx: 9
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([6, 4, 9, 8])
# Scores tensor([ 5.7552,  2.2598, -4.4322,  4.6599], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([6., 4., 9., 8.])
# tensor(122.8280, grad_fn=<DivBackward1>)
# Loss:  122.82799530029297
# ['he', 'is', 'king', '.'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([3, 4, 0, 8])
# Scores tensor([ 5.1743, -6.1132,  2.9265, -9.1181], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([3., 4., 0., 8.])
# tensor(160.9957, grad_fn=<DivBackward1>)
# Loss:  160.9957275390625
# ['is', 'the', '.', 'the'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12,  8, 12])
# Scores tensor([-7.3431, -2.9218,  8.2695, -2.9218], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12.,  8., 12.])
# tensor(331.0421, grad_fn=<DivBackward1>)
# Loss:  331.0421142578125
# ['the', 'king', 'the', 'king'] .
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0, 12,  0])
# Scores tensor([12.4348, -1.0746, 12.4348, -1.0746], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0., 12.,  0.])
# tensor(16.6356, grad_fn=<DivBackward1>)
# Loss:  16.63556671142578
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([ 2.8496, -8.3806,  2.8496, -5.8004], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(132.7608, grad_fn=<DivBackward1>)
# Loss:  132.7608184814453
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([ 7.2858, -2.1691, -7.2831,  8.4757], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(207.9955, grad_fn=<DivBackward1>)
# Loss:  207.99546813964844
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([ 4.0841, -5.2712,  1.3977,  2.2688], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(29.1035, grad_fn=<DivBackward1>)
# Loss:  29.103500366210938
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([ 2.2248, -1.4630, -9.4356, -1.4630], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(100.1489, grad_fn=<DivBackward1>)
# Loss:  100.14892578125
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([-9.8727,  3.7789, -9.8727,  3.9710], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(126.7522, grad_fn=<DivBackward1>)
# Loss:  126.75221252441406
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([ 1.7266,  2.5823,  3.1859, 21.4063], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(429.9868, grad_fn=<DivBackward1>)
# Loss:  429.98675537109375
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([-10.0891,  -5.3565,  -5.9051,  -6.8865], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(63.4533, grad_fn=<DivBackward1>)
# Loss:  63.45331954956055
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([-4.0357, 13.5405,  1.9465, 16.0929], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(255.1581, grad_fn=<DivBackward1>)
# Loss:  255.15809631347656
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-7.4801,  5.1147,  0.6694, 11.6795], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(363.9907, grad_fn=<DivBackward1>)
# Loss:  363.9906921386719
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# Scores tensor([ 8.5540, -3.4615,  1.2501, -2.5114], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 7., 10.,  3.,  4.])
# tensor(186.3443, grad_fn=<DivBackward1>)
# Loss:  186.34426879882812
# ['queen', '.', 'is', 'a'] he
# Max context_idx: 10
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([10,  8,  4,  2])
# Scores tensor([2.0901, 0.4365, 4.7605, 1.3868], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([10.,  8.,  4.,  2.])
# tensor(70.6931, grad_fn=<DivBackward1>)
# Loss:  70.69309997558594
# ['.', 'he', 'a', 'prince,'] is
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 8,  3,  2, 11])
# Scores tensor([ 6.3427, -1.3539, -7.8639,  0.6836], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8.,  3.,  2., 11.])
# tensor(113.8484, grad_fn=<DivBackward1>)
# Loss:  113.84839630126953
# ['he', 'is', 'prince,', 'and'] a
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([ 3,  4, 11,  1])
# Scores tensor([ 1.5242,  2.3813,  0.5945, -4.6278], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 3.,  4., 11.,  1.])
# tensor(38.0794, grad_fn=<DivBackward1>)
# Loss:  38.07942199707031
# ['is', 'a', 'and', 'she'] prince,
# Max context_idx: 6
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([4, 2, 1, 6])
# Scores tensor([ 6.6020,  2.6582,  4.3313, -2.3389], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([4., 2., 1., 6.])
# tensor(65.3084, grad_fn=<DivBackward1>)
# Loss:  65.30842590332031
# ['a', 'prince,', 'she', 'is'] and
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 2, 11,  6,  4])
# Scores tensor([  1.4646,  -8.2012,  12.9973, -14.8768], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 2., 11.,  6.,  4.])
# tensor(367.7454, grad_fn=<DivBackward1>)
# Loss:  367.7453918457031
# ['prince,', 'and', 'is', 'a'] she
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([11,  1,  4,  2])
# Scores tensor([ 13.4948, -16.2919,  -9.1113,  -5.0651], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([11.,  1.,  4.,  2.])
# tensor(157.3308, grad_fn=<DivBackward1>)
# Loss:  157.33082580566406
# ['and', 'she', 'a', 'princess'] is
# Max context_idx: 9
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([1, 6, 2, 9])
# Scores tensor([ 0.9624,  2.6966, -7.8594,  2.1872], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([1., 6., 2., 9.])
# tensor(37.7838, grad_fn=<DivBackward1>)
# Loss:  37.78379821777344
# ['she', 'is', 'princess', '.'] a
# Max context_idx: 9
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([6, 4, 9, 8])
# Scores tensor([ 4.7764,  1.7452, -3.8573,  4.4157], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([6., 4., 9., 8.])
# tensor(107.7549, grad_fn=<DivBackward1>)
# Loss:  107.75489807128906
# ['he', 'is', 'king', '.'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([3, 4, 0, 8])
# Scores tensor([ 4.3922, -5.9828,  2.0838, -7.6323], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([3., 4., 0., 8.])
# tensor(139.1185, grad_fn=<DivBackward1>)
# Loss:  139.1185302734375
# ['is', 'the', '.', 'the'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12,  8, 12])
# Scores tensor([-7.2406, -1.5948,  7.3069, -1.5948], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12.,  8., 12.])
# tensor(271.8410, grad_fn=<DivBackward1>)
# Loss:  271.84100341796875
# ['the', 'king', 'the', 'king'] .
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0, 12,  0])
# Scores tensor([12.4877, -0.9262, 12.4877, -0.9262], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0., 12.,  0.])
# tensor(16.6356, grad_fn=<DivBackward1>)
# Loss:  16.63556671142578
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([ 2.0132, -6.9011,  2.0132, -5.6732], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(110.3821, grad_fn=<DivBackward1>)
# Loss:  110.38212585449219
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([ 6.3274, -0.8428, -7.1798,  7.8054], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(181.5061, grad_fn=<DivBackward1>)
# Loss:  181.5061492919922
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([ 3.7942, -5.2682,  1.9263,  2.0030], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(26.4950, grad_fn=<DivBackward1>)
# Loss:  26.495012283325195
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([ 1.3204, -1.0496, -8.8960, -1.0496], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(82.6577, grad_fn=<DivBackward1>)
# Loss:  82.6577377319336
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([-8.6179,  3.2448, -8.6179,  3.5310], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(112.6290, grad_fn=<DivBackward1>)
# Loss:  112.62902069091797
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([ 2.1424,  2.4163,  2.8958, 20.4381], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(410.1166, grad_fn=<DivBackward1>)
# Loss:  410.1165771484375
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([-9.6089, -5.2368, -5.9149, -6.3080], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(58.4868, grad_fn=<DivBackward1>)
# Loss:  58.486751556396484
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([-3.7497, 13.8455,  2.3267, 15.1179], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(227.0482, grad_fn=<DivBackward1>)
# Loss:  227.0481719970703
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-7.1050,  5.3443,  0.9823, 10.8333], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(332.6155, grad_fn=<DivBackward1>)
# Loss:  332.6155090332031
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# Scores tensor([ 7.6170, -2.9278,  1.4277, -2.3587], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 7., 10.,  3.,  4.])
# tensor(163.9690, grad_fn=<DivBackward1>)
# Loss:  163.968994140625
# ['queen', '.', 'is', 'a'] he
# Max context_idx: 10
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([10,  8,  4,  2])
# Scores tensor([2.4265, 1.1643, 3.8268, 1.2634], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([10.,  8.,  4.,  2.])
# tensor(48.3907, grad_fn=<DivBackward1>)
# Loss:  48.39070129394531
# ['.', 'he', 'a', 'prince,'] is
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 8,  3,  2, 11])
# Scores tensor([ 5.2593, -1.4073, -7.2133,  1.1587], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8.,  3.,  2., 11.])
# tensor(90.4764, grad_fn=<DivBackward1>)
# Loss:  90.47640991210938
# ['he', 'is', 'prince,', 'and'] a
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([ 3,  4, 11,  1])
# Scores tensor([ 1.3552,  1.9078,  1.3220, -4.5516], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 3.,  4., 11.,  1.])
# tensor(28.9601, grad_fn=<DivBackward1>)
# Loss:  28.96007537841797
# ['is', 'a', 'and', 'she'] prince,
# Max context_idx: 6
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([4, 2, 1, 6])
# Scores tensor([ 5.9684,  2.8707,  4.3090, -1.7223], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([4., 2., 1., 6.])
# tensor(56.7519, grad_fn=<DivBackward1>)
# Loss:  56.75185775756836
# ['a', 'prince,', 'she', 'is'] and
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 2, 11,  6,  4])
# Scores tensor([  1.4220,  -7.7658,  12.2692, -14.7163], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 2., 11.,  6.,  4.])
# tensor(350.0212, grad_fn=<DivBackward1>)
# Loss:  350.02117919921875
# ['prince,', 'and', 'is', 'a'] she
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([11,  1,  4,  2])
# Scores tensor([ 12.6715, -16.2108,  -7.8500,  -4.6638], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([11.,  1.,  4.,  2.])
# tensor(145.6386, grad_fn=<DivBackward1>)
# Loss:  145.6386260986328
# ['and', 'she', 'a', 'princess'] is
# Max context_idx: 9
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([1, 6, 2, 9])
# Scores tensor([ 0.4540,  2.5299, -7.2090,  2.9042], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([1., 6., 2., 9.])
# tensor(35.2415, grad_fn=<DivBackward1>)
# Loss:  35.24150848388672
# ['she', 'is', 'princess', '.'] a
# Max context_idx: 9
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([6, 4, 9, 8])
# Scores tensor([ 3.9244,  1.3175, -3.2115,  3.7903], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([6., 4., 9., 8.])
# tensor(93.7425, grad_fn=<DivBackward1>)
# Loss:  93.74250030517578
# ['he', 'is', 'king', '.'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([3, 4, 0, 8])
# Scores tensor([ 3.6367, -5.9109,  1.2393, -6.1345], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([3., 4., 0., 8.])
# tensor(117.6675, grad_fn=<DivBackward1>)
# Loss:  117.66746520996094
# ['is', 'the', '.', 'the'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12,  8, 12])
# Scores tensor([-7.1564, -0.3025,  6.4277, -0.3025], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12.,  8., 12.])
# tensor(215.9482, grad_fn=<DivBackward1>)
# Loss:  215.94822692871094
# ['the', 'king', 'the', 'king'] .
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0, 12,  0])
# Scores tensor([12.5437, -0.7782, 12.5437, -0.7782], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0., 12.,  0.])
# tensor(16.6356, grad_fn=<DivBackward1>)
# Loss:  16.63557243347168
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([ 1.1768, -5.4098,  1.1768, -5.6050], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(88.1522, grad_fn=<DivBackward1>)
# Loss:  88.15217590332031
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([ 5.4517,  0.4489, -7.0946,  7.1064], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(155.0350, grad_fn=<DivBackward1>)
# Loss:  155.03504943847656
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([ 3.5418, -5.1845,  2.4262,  2.2943], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(24.0892, grad_fn=<DivBackward1>)
# Loss:  24.08919906616211
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([ 0.4181, -0.6789, -8.3237, -0.6789], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(68.3885, grad_fn=<DivBackward1>)
# Loss:  68.38850402832031
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([-7.3587,  2.7615, -7.3587,  3.0170], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(98.6227, grad_fn=<DivBackward1>)
# Loss:  98.62274169921875
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([ 2.4141,  2.8725,  2.6999, 19.4797], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(386.3297, grad_fn=<DivBackward1>)
# Loss:  386.32965087890625
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([-9.1230, -5.1875, -5.8281, -5.8305], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(54.2004, grad_fn=<DivBackward1>)
# Loss:  54.200355529785156
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([-3.4357, 14.0328,  2.7822, 14.1516], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(207.0761, grad_fn=<DivBackward1>)
# Loss:  207.0761260986328
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-6.6763,  5.5705,  1.2805,  9.9912], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(301.0034, grad_fn=<DivBackward1>)
# Loss:  301.00335693359375
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# Scores tensor([ 6.6861, -2.3803,  1.6072, -2.2039], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 7., 10.,  3.,  4.])
# tensor(141.6159, grad_fn=<DivBackward1>)
# Loss:  141.61587524414062
# ['queen', '.', 'is', 'a'] he
# Max context_idx: 10
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([10,  8,  4,  2])
# Scores tensor([2.6864, 1.9681, 2.8908, 1.0556], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([10.,  8.,  4.,  2.])
# tensor(33.8271, grad_fn=<DivBackward1>)
# Loss:  33.827083587646484
# ['.', 'he', 'a', 'prince,'] is
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 8,  3,  2, 11])
# Scores tensor([ 4.4029, -1.4876, -6.1270,  1.6418], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8.,  3.,  2., 11.])
# tensor(70.6374, grad_fn=<DivBackward1>)
# Loss:  70.63743591308594
# ['he', 'is', 'prince,', 'and'] a
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([ 3,  4, 11,  1])
# Scores tensor([ 1.1032,  1.4782,  2.0521, -4.4447], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 3.,  4., 11.,  1.])
# tensor(24.3474, grad_fn=<DivBackward1>)
# Loss:  24.347423553466797
# ['is', 'a', 'and', 'she'] prince,
# Max context_idx: 6
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([4, 2, 1, 6])
# Scores tensor([ 5.4042,  3.1168,  4.1681, -1.0460], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([4., 2., 1., 6.])
# tensor(48.8273, grad_fn=<DivBackward1>)
# Loss:  48.82728958129883
# ['a', 'prince,', 'she', 'is'] and
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 2, 11,  6,  4])
# Scores tensor([  1.3783,  -7.3255,  11.5482, -14.5518], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 2., 11.,  6.,  4.])
# tensor(332.3508, grad_fn=<DivBackward1>)
# Loss:  332.3507995605469
# ['prince,', 'and', 'is', 'a'] she
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([11,  1,  4,  2])
# Scores tensor([ 11.8607, -16.1488,  -6.5974,  -4.2712], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([11.,  1.,  4.,  2.])
# tensor(134.1058, grad_fn=<DivBackward1>)
# Loss:  134.1057586669922
# ['and', 'she', 'a', 'princess'] is
# Max context_idx: 9
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([1, 6, 2, 9])
# Scores tensor([ 0.0464,  2.9826, -6.1185,  2.6150], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([1., 6., 2., 9.])
# tensor(34.4744, grad_fn=<DivBackward1>)
# Loss:  34.47435760498047
# ['she', 'is', 'princess', '.'] a
# Max context_idx: 9
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([6, 4, 9, 8])
# Scores tensor([ 3.1031,  0.8154, -2.5183,  3.0365], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([6., 4., 9., 8.])
# tensor(79.5355, grad_fn=<DivBackward1>)
# Loss:  79.53546142578125
# ['he', 'is', 'king', '.'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([3, 4, 0, 8])
# Scores tensor([ 2.9061, -5.8623,  0.3996, -4.6165], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([3., 4., 0., 8.])
# tensor(96.4407, grad_fn=<DivBackward1>)
# Loss:  96.44074249267578
# ['is', 'the', '.', 'the'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12,  8, 12])
# Scores tensor([-7.1042,  1.0094,  5.5819,  1.0094], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12.,  8., 12.])
# tensor(161.2212, grad_fn=<DivBackward1>)
# Loss:  161.22122192382812
# ['the', 'king', 'the', 'king'] .
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0, 12,  0])
# Scores tensor([12.5910, -0.6310, 12.5910, -0.6310], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0., 12.,  0.])
# tensor(16.6356, grad_fn=<DivBackward1>)
# Loss:  16.635578155517578
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([ 0.3459, -3.8980,  0.3459, -5.5598], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(65.9938, grad_fn=<DivBackward1>)
# Loss:  65.99382019042969
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([ 4.6074,  1.7587, -7.0391,  6.3884], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(128.2702, grad_fn=<DivBackward1>)
# Loss:  128.2702178955078
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([ 3.3258, -5.1280,  2.5974,  2.1798], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(24.0474, grad_fn=<DivBackward1>)
# Loss:  24.0473690032959
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([-0.4603, -0.4460, -7.6126, -0.4460], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(58.3172, grad_fn=<DivBackward1>)
# Loss:  58.317230224609375
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([-6.1015,  2.2679, -6.1015,  2.5015], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(84.5759, grad_fn=<DivBackward1>)
# Loss:  84.575927734375
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([ 2.0676,  2.9339,  2.9122, 18.5192], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(363.0533, grad_fn=<DivBackward1>)
# Loss:  363.0533142089844
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([-8.5363, -5.1806, -5.6962, -5.4690], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(50.0561, grad_fn=<DivBackward1>)
# Loss:  50.056121826171875
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([-3.0219, 13.7320,  3.4206, 13.3776], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(191.0382, grad_fn=<DivBackward1>)
# Loss:  191.0382080078125
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-6.1706,  5.7886,  1.5512,  9.1540], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(269.3085, grad_fn=<DivBackward1>)
# Loss:  269.30853271484375
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# Scores tensor([ 5.7629, -1.8170,  1.7851, -2.0426], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 7., 10.,  3.,  4.])
# tensor(119.4211, grad_fn=<DivBackward1>)
# Loss:  119.421142578125
# ['queen', '.', 'is', 'a'] he
# Max context_idx: 10
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([10,  8,  4,  2])
# Scores tensor([2.7922, 2.8959, 1.9717, 0.9431], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([10.,  8.,  4.,  2.])
# tensor(30.0495, grad_fn=<DivBackward1>)
# Loss:  30.04952621459961
# ['.', 'he', 'a', 'prince,'] is
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 8,  3,  2, 11])
# Scores tensor([ 3.4495, -1.4836, -5.6230,  2.0186], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8.,  3.,  2., 11.])
# tensor(53.9701, grad_fn=<DivBackward1>)
# Loss:  53.97013854980469
# ['he', 'is', 'prince,', 'and'] a
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([ 3,  4, 11,  1])
# Scores tensor([ 0.8124,  0.9069,  2.5484, -4.0014], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 3.,  4., 11.,  1.])
# tensor(24.3240, grad_fn=<DivBackward1>)
# Loss:  24.323986053466797
# ['is', 'a', 'and', 'she'] prince,
# Max context_idx: 6
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([4, 2, 1, 6])
# Scores tensor([ 4.8924,  3.3722,  3.9250, -0.2987], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([4., 2., 1., 6.])
# tensor(41.2991, grad_fn=<DivBackward1>)
# Loss:  41.29906463623047
# ['a', 'prince,', 'she', 'is'] and
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 2, 11,  6,  4])
# Scores tensor([  1.3476,  -6.8401,  10.8368, -14.3707], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 2., 11.,  6.,  4.])
# tensor(314.2570, grad_fn=<DivBackward1>)
# Loss:  314.25701904296875
# ['prince,', 'and', 'is', 'a'] she
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([11,  1,  4,  2])
# Scores tensor([ 11.1064, -16.0899,  -5.4540,  -3.9057], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([11.,  1.,  4.,  2.])
# tensor(123.4625, grad_fn=<DivBackward1>)
# Loss:  123.4625015258789
# ['and', 'she', 'a', 'princess'] is
# Max context_idx: 9
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([1, 6, 2, 9])
# Scores tensor([-0.1300,  3.0483, -5.5877,  3.1998], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([1., 6., 2., 9.])
# tensor(33.3233, grad_fn=<DivBackward1>)
# Loss:  33.32330322265625
# ['she', 'is', 'princess', '.'] a
# Max context_idx: 9
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([6, 4, 9, 8])
# Scores tensor([ 2.5076,  1.2279, -1.7785,  2.3649], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([6., 4., 9., 8.])
# tensor(65.6140, grad_fn=<DivBackward1>)
# Loss:  65.61404418945312
# ['he', 'is', 'king', '.'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([3, 4, 0, 8])
# Scores tensor([ 2.1619, -5.8539, -0.4214, -3.1340], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([3., 4., 0., 8.])
# tensor(75.5971, grad_fn=<DivBackward1>)
# Loss:  75.59706115722656
# ['is', 'the', '.', 'the'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12,  8, 12])
# Scores tensor([-6.9783,  2.3490,  4.8022,  2.3490], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12.,  8., 12.])
# tensor(111.7134, grad_fn=<DivBackward1>)
# Loss:  111.71337890625
# ['the', 'king', 'the', 'king'] .
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0, 12,  0])
# Scores tensor([12.6512, -0.4875, 12.6512, -0.4875], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0., 12.,  0.])
# tensor(16.6356, grad_fn=<DivBackward1>)
# Loss:  16.635578155517578
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([-0.4698, -2.4216, -0.4698, -5.5517], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(45.1180, grad_fn=<DivBackward1>)
# Loss:  45.11795425415039
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([ 3.8198,  3.0821, -6.8910,  5.6371], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(101.5524, grad_fn=<DivBackward1>)
# Loss:  101.55243682861328
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([ 3.5648, -5.0257,  2.3051,  2.3871], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(24.0583, grad_fn=<DivBackward1>)
# Loss:  24.05831527709961
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([-1.1628, -0.5612, -6.7026, -0.5612], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(49.9541, grad_fn=<DivBackward1>)
# Loss:  49.954139709472656
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([-4.9510,  1.7713, -4.9510,  1.9853], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(71.3835, grad_fn=<DivBackward1>)
# Loss:  71.38352966308594
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([ 2.4660,  2.8238,  2.6779, 17.6106], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(343.6358, grad_fn=<DivBackward1>)
# Loss:  343.6358337402344
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([-7.8444, -5.1791, -5.5464, -5.2338], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(46.0175, grad_fn=<DivBackward1>)
# Loss:  46.01746368408203
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([-2.6780, 13.1017,  4.0553, 13.0221], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(176.4621, grad_fn=<DivBackward1>)
# Loss:  176.46206665039062
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-5.7284,  5.9872,  1.8883,  8.3177], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(239.1299, grad_fn=<DivBackward1>)
# Loss:  239.12989807128906
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# ...
# Loss:  16.63561248779297
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([-2.7776,  0.0163, -2.7776, -4.3961], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(19.1640, grad_fn=<DivBackward1>)
# Loss:  19.16397476196289
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([ 3.6568,  3.2014, -5.0314,  3.4380], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(67.1540, grad_fn=<DivBackward1>)
# Loss:  67.1539535522461
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([ 3.9710, -4.9668,  2.6567,  3.1006], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(23.8297, grad_fn=<DivBackward1>)
# Loss:  23.829652786254883
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([-2.4576, -1.5523, -3.9474, -1.5523], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(27.1741, grad_fn=<DivBackward1>)
# Loss:  27.174114227294922
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([-1.4235,  0.2713, -1.4235,  0.5714], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(34.9482, grad_fn=<DivBackward1>)
# Loss:  34.94817352294922
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([ 3.1645,  3.1707,  3.1509, 14.8670], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(269.2842, grad_fn=<DivBackward1>)
# Loss:  269.28424072265625
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([-6.2241, -3.6098, -4.9946, -4.4889], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(49.1054, grad_fn=<DivBackward1>)
# Loss:  49.10543441772461
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([-1.7687, 11.6668,  6.1598, 11.2957], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(129.7019, grad_fn=<DivBackward1>)
# Loss:  129.70191955566406
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-4.0765,  6.0065,  2.9105,  6.1386], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(168.8358, grad_fn=<DivBackward1>)
# Loss:  168.83575439453125
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# Scores tensor([ 2.4423,  0.7669,  1.9576, -1.3503], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 7., 10.,  3.,  4.])
# tensor(47.8248, grad_fn=<DivBackward1>)
# Loss:  47.824832916259766
# ['queen', '.', 'is', 'a'] he
# Max context_idx: 10
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([10,  8,  4,  2])
# Scores tensor([2.0185, 3.0676, 1.5899, 0.8649], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([10.,  8.,  4.,  2.])
# tensor(33.3852, grad_fn=<DivBackward1>)
# Loss:  33.385154724121094
# ['.', 'he', 'a', 'prince,'] is
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 8,  3,  2, 11])
# Scores tensor([ 0.9955, -0.9087, -2.0069,  1.5374], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8.,  3.,  2., 11.])
# tensor(31.4569, grad_fn=<DivBackward1>)
# Loss:  31.45693588256836
# ['he', 'is', 'prince,', 'and'] a
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([ 3,  4, 11,  1])
# Scores tensor([ 0.1807, -0.0380,  1.8592, -2.6941], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 3.,  4., 11.,  1.])
# tensor(22.8396, grad_fn=<DivBackward1>)
# Loss:  22.839580535888672
# ['is', 'a', 'and', 'she'] prince,
# Max context_idx: 6
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([4, 2, 1, 6])
# Scores tensor([3.6677, 3.4142, 2.8562, 3.1327], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([4., 2., 1., 6.])
# tensor(17.9410, grad_fn=<DivBackward1>)
# Loss:  17.940990447998047
# ['a', 'prince,', 'she', 'is'] and
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 2, 11,  6,  4])
# Scores tensor([  1.1981,  -4.9836,   7.9840, -13.4251], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 2., 11.,  6.,  4.])
# tensor(241.8788, grad_fn=<DivBackward1>)
# Loss:  241.8787841796875
# ['prince,', 'and', 'is', 'a'] she
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([11,  1,  4,  2])
# Scores tensor([  8.0167, -15.8965,  -0.8425,  -2.5137], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([11.,  1.,  4.,  2.])
# tensor(80.4141, grad_fn=<DivBackward1>)
# Loss:  80.41410827636719
# ['and', 'she', 'a', 'princess'] is
# Max context_idx: 9
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([1, 6, 2, 9])
# Scores tensor([-0.5865,  3.5116, -1.6353,  3.0688], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([1., 6., 2., 9.])
# tensor(27.5501, grad_fn=<DivBackward1>)
# Loss:  27.550146102905273
# ['she', 'is', 'princess', '.'] a
# Max context_idx: 9
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([6, 4, 9, 8])
# Scores tensor([0.3286, 0.3775, 1.3719, 0.6885], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([6., 4., 9., 8.])
# tensor(37.3240, grad_fn=<DivBackward1>)
# Loss:  37.3239631652832
# ['he', 'is', 'king', '.'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([3, 4, 0, 8])
# Scores tensor([-0.8536, -4.4109, -3.1640, -0.7594], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([3., 4., 0., 8.])
# tensor(25.4822, grad_fn=<DivBackward1>)
# Loss:  25.482206344604492
# ['is', 'the', '.', 'the'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12,  8, 12])
# Scores tensor([-4.6734,  3.8656,  3.0654,  3.8656], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12.,  8., 12.])
# tensor(72.8085, grad_fn=<DivBackward1>)
# Loss:  72.8084945678711
# ['the', 'king', 'the', 'king'] .
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0, 12,  0])
# Scores tensor([12.3087, -0.0928, 12.3087, -0.0928], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0., 12.,  0.])
# tensor(16.6356, grad_fn=<DivBackward1>)
# Loss:  16.635629653930664
# ['king', '.', 'king', 'is'] the
# Max context_idx: 8
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 8, 0, 4])
# Scores tensor([-3.3497, -0.6378, -3.3497, -3.6700], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 8., 0., 4.])
# tensor(14.1254, grad_fn=<DivBackward1>)
# Loss:  14.125406265258789
# ['.', 'the', 'is', 'royal.'] king
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 8, 12,  4,  5])
# Scores tensor([ 3.4218,  2.9371, -4.0609,  3.0471], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8., 12.,  4.,  5.])
# tensor(61.8247, grad_fn=<DivBackward1>)
# Loss:  61.82469177246094
# ['the', 'king', 'royal.', 'she'] is
# Max context_idx: 12
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([12,  0,  5,  6])
# Scores tensor([ 3.6746, -5.0488,  3.3320,  2.7282], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  0.,  5.,  6.])
# tensor(24.4366, grad_fn=<DivBackward1>)
# Loss:  24.436582565307617
# ['king', 'is', 'she', 'is'] royal.
# Max context_idx: 6
# Min context_idx: 0
# context_idx shape: torch.Size([4])
# tensor([0, 4, 6, 4])
# Scores tensor([-2.8448, -1.8966, -3.0710, -1.8966], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([0., 4., 6., 4.])
# tensor(20.9332, grad_fn=<DivBackward1>)
# Loss:  20.933197021484375
# ['is', 'royal.', 'is', 'the'] she
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4,  5,  4, 12])
# Scores tensor([-0.3173, -0.3154, -0.3173,  0.2387], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4.,  5.,  4., 12.])
# tensor(32.2489, grad_fn=<DivBackward1>)
# Loss:  32.24894714355469
# ['royal.', 'she', 'the', 'royal'] is
# Max context_idx: 12
# Min context_idx: 5
# context_idx shape: torch.Size([4])
# tensor([ 5,  6, 12,  7])
# Scores tensor([ 2.5678,  3.2332,  3.9381, 13.8416], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 5.,  6., 12.,  7.])
# tensor(238.8633, grad_fn=<DivBackward1>)
# Loss:  238.86328125
# ['she', 'is', 'royal', 'queen'] the
# Max context_idx: 10
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 6,  4,  7, 10])
# Scores tensor([-5.9931, -2.9747, -4.6888, -4.0505], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 6.,  4.,  7., 10.])
# tensor(53.0471, grad_fn=<DivBackward1>)
# Loss:  53.047088623046875
# ['is', 'the', 'queen', '.'] royal
# Max context_idx: 12
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([ 4, 12, 10,  8])
# Scores tensor([-1.5547, 11.1058,  6.7920, 10.8188], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 4., 12., 10.,  8.])
# tensor(115.3728, grad_fn=<DivBackward1>)
# Loss:  115.37275695800781
# ['the', 'royal', '.', 'he'] queen
# Max context_idx: 12
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([12,  7,  8,  3])
# Scores tensor([-3.4309,  5.6500,  3.3618,  5.6330], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([12.,  7.,  8.,  3.])
# tensor(149.3654, grad_fn=<DivBackward1>)
# Loss:  149.3654022216797
# ['royal', 'queen', 'he', 'is'] .
# Max context_idx: 10
# Min context_idx: 3
# context_idx shape: torch.Size([4])
# tensor([ 7, 10,  3,  4])
# Scores tensor([ 1.8928,  1.4728,  1.5856, -0.9627], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 7., 10.,  3.,  4.])
# tensor(38.0507, grad_fn=<DivBackward1>)
# Loss:  38.050724029541016
# ['queen', '.', 'is', 'a'] he
# Max context_idx: 10
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([10,  8,  4,  2])
# Scores tensor([2.5810, 2.0693, 1.5938, 0.7109], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([10.,  8.,  4.,  2.])
# tensor(29.8867, grad_fn=<DivBackward1>)
# Loss:  29.88669204711914
# ['.', 'he', 'a', 'prince,'] is
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 8,  3,  2, 11])
# Scores tensor([ 0.8501, -0.5312, -1.3462,  0.6075], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 8.,  3.,  2., 11.])
# tensor(29.5434, grad_fn=<DivBackward1>)
# Loss:  29.54336166381836
# ['he', 'is', 'prince,', 'and'] a
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([ 3,  4, 11,  1])
# Scores tensor([ 0.4037,  0.4890,  1.0815, -2.4095], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 3.,  4., 11.,  1.])
# tensor(21.9110, grad_fn=<DivBackward1>)
# Loss:  21.91095733642578
# ['is', 'a', 'and', 'she'] prince,
# Max context_idx: 6
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([4, 2, 1, 6])
# Scores tensor([3.4742, 3.1994, 2.6096, 3.9877], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([4., 2., 1., 6.])
# tensor(15.8652, grad_fn=<DivBackward1>)
# Loss:  15.865167617797852
# ['a', 'prince,', 'she', 'is'] and
# Max context_idx: 11
# Min context_idx: 2
# context_idx shape: torch.Size([4])
# tensor([ 2, 11,  6,  4])
# Scores tensor([  1.1671,  -4.5475,   7.2406, -13.2934], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([ 2., 11.,  6.,  4.])
# tensor(224.0050, grad_fn=<DivBackward1>)
# Loss:  224.0050048828125
# ['prince,', 'and', 'is', 'a'] she
# Max context_idx: 11
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([11,  1,  4,  2])
# Scores tensor([  7.1855, -15.7963,  -0.9828,  -2.3985], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([11.,  1.,  4.,  2.])
# tensor(74.8295, grad_fn=<DivBackward1>)
# Loss:  74.82946014404297
# ['and', 'she', 'a', 'princess'] is
# Max context_idx: 9
# Min context_idx: 1
# context_idx shape: torch.Size([4])
# tensor([1, 6, 2, 9])
# Scores tensor([-0.6703,  3.3672, -1.2755,  3.5954], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([1., 6., 2., 9.])
# tensor(26.1328, grad_fn=<DivBackward1>)
# Loss:  26.132766723632812
# ['she', 'is', 'princess', '.'] a
# Max context_idx: 9
# Min context_idx: 4
# context_idx shape: torch.Size([4])
# tensor([6, 4, 9, 8])
# Scores tensor([0.6268, 0.0741, 0.5553, 1.3192], grad_fn=<SqueezeBackward0>)
# Scores shape: torch.Size([4])
# Score dtype:  torch.float32
# context_idx dtype:  torch.int64
# context_idx:  tensor([6., 4., 9., 8.])
# tensor(37.9546, grad_fn=<DivBackward1>)
# Loss:  37.954627990722656
# Epoch [10/10], Loss: 63.0154

# %% [markdown]
# ### Evaluate Model

# %%
# Step 7: Evaluation
def most_similar(word, word2idx, idx2word, embedding_matrix, topk=5):
    word_embedding = embedding_matrix[word2idx[word]]
    similarities = cosine_similarity([word_embedding], embedding_matrix)[0]
    print([tup for tup in zip(idx2word.values(), similarities)])
    similar_words = [(idx2word[idx], similarities[idx]) for idx in np.argsort(similarities, axis=-1)[-topk-1:-1][::-1]]
    return similar_words

# %%
embedding_matrix = model.in_embed.weight.data.numpy()
# print(embedding_matrix) # Debug line
most_similar_words = most_similar('king', word2idx, idx2word, embedding_matrix, topk=5)
print(most_similar_words)
# Out:
# [('king', 1.0), ('and', 0.0076950155), ('a', 0.2688496), ('he', -0.07239942), ('is', 0.09491261), ('royal.', 0.033431225), ('she', -0.116904765), ('royal', -0.22678074), ('.', 0.23785788), ('princess', -0.067026526), ('queen', 0.06646336), ('prince,', -0.104524344), ('the', 0.082939275)]
# [('a', 0.2688496), ('.', 0.23785788), ('is', 0.09491261), ('the', 0.082939275), ('queen', 0.06646336)]

# %% [markdown]
# ## Using word2vec for Text Classification
